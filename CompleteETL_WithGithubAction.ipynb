# 24                                在鸿蒙NEXT中开发一个2048小游戏  2025-03-23T12:55:48Z
#
#                Author                                 Tags Reading Time  \
# 0    Shailendra Singh      #vue#javascript#frontend#webdev   4 min read
# 1        Tharun Reddy              #devops#cloud#linux#aws   2 min read
# 2      Thomas Künneth                      #kotlin#cmp#kmp   5 min read
# 3               m1rr4                                        2 min read
# 4           wei chang                                        1 min read
# 5               MCnad            #showdev#webdev#rag#genai   5 min read
# 6           wei chang                                        2 min read
# 7        Mayank Gupta  #mcp#ai#machinelearning#programming   4 min read
# 8    GitHubOpenSource      #bittorrent#indexer#dht#graphql   3 min read
# 9           wei chang                                        2 min read
# 10          wei chang                                        1 min read
# 11          wei chang                                        2 min read
# 12          wei chang                                        2 min read
# 13            Ashwani           #cto#tooling#buildinpublic   4 min read
# 14          wei chang                                        1 min read
# 15          wei chang                                        2 min read
# 16          wei chang                                        2 min read
# 17          wei chang                                        2 min read
# 18  vrauuss softwares                                        2 min read
# 19          wei chang                                        2 min read
# 20          wei chang                                        3 min read
# 21          wei chang                                        1 min read
# 22       Adan Alvarez                    #aws#security#rag   3 min read
# 23         Smart Mohr                                        6 min read
# 24          wei chang                                        2 min read
#
#                                       Article Content  Word Count Sentiment  \
# 0   A few days back I was trying to integrate hCap...         476  Negative
# 1   Starting my DevOps journey, I set out to launc...         152  Positive
# 2   This is the second article in a series of tips...         632  Positive
# 3   Quando manipulamos o DOM (Document Object Mode...         286  Negative
# 4   上次写过一篇使用uni-app开发鸿蒙的文章，但是当时幽蓝君的编译器还没有编译到鸿蒙的选项，...          20   Neutral
# 5   In the market for generic RAG frameworks, the ...         865  Positive
# 6   幽蓝君前几日收到了华为的邀请，正式加入鸿蒙生态。今天开始会和大家分享HarmonyOS NE...          43   Neutral
# 7   We've all been there—you ask an AI assistant a...         360  Positive
# 8   Bitmagnet is a self-hosted BitTorrent indexer ...         411  Positive
# 9   上次写过一次鸿蒙的音乐项目，不过是基于api9，最近幽蓝君把它完善优化，并适配到api 12...          16   Neutral
# 10  随着鸿蒙系统5.0的发布，兼容的机型越来越多，对于开发者来说机会也越来越多，大家不要气馁，学...          11   Neutral
# 11  鸿蒙系统发布以后都不知道叫它5.0版本还是NEXT版本了，哈哈，反正是最新版本就对了。\n对...           8   Neutral
# 12  今天的内容是介绍在鸿蒙开发中从相册选择照片，和调用相机拍照，并使用这两个功能实现朋友圈编辑页...           7   Neutral
# 13  The first in a series on how engineering leade...         454  Positive
# 14  今天的实战教程是简单模仿一下抖音短视频，主要是首页部分的内容，先看效果图:  下面为大家讲解...          12   Neutral
# 15  这是之前写过的一个项目，后来删掉了，现在适配到api12重新发布，友友们按需查阅。 本文主要...           9   Neutral
# 16  今天忙里偷闲，分享一个搜索页实现过程，先上效果图：  界面部分比较简单，大体分为导航栏、历史...           6   Neutral
# 17  幽蓝君最近发现小红书是个好东西，一定要多逛 今天就浅浅模仿一下小红书app，主要是底部tab...           6   Neutral
# 18   This plugin transforms SVG files into React c...          12   Neutral
# 19  今天跟大家分享一个ocr文字识别的小项目：  鸿蒙系统提供了文字识别的能力，支持简体中文、英...           6   Neutral
# 20  一早醒来Mate70上热搜了，余承东发文宣布Mate70要在本月发布，史上最强手机终于要来了...          12   Neutral
# 21  昨天Mate70的官方预热直接引起网络爆炸，现在预约人数已经两百多万了，大家都这么有米吗 今...          10   Neutral
# 22   Security questionnaires are very common today...         367  Positive
# 23  The complexity of contemporary software develo...         985  Positive
# 24  本项目是基于api12开发的2048游戏，游戏的逻辑是当用户向某个方向滑动时，将该方向相邻且...           9   Neutral
#
#     Compound Score
# 0          -0.8911
# 1           0.9801
# 2           0.9970
# 3          -0.6808
# 4           0.0000
# 5           0.9984
# 6           0.0000
# 7           0.9714
# 8           0.9978
# 9           0.0000
# 10          0.0000
# 11          0.0000
# 12          0.0000
# 13          0.9990
# 14          0.0000
# 15          0.0000
# 16          0.0000
# 17          0.0000
# 18          0.0000
# 19          0.0000
# 20          0.0000
# 21          0.0000
# 22          0.9940
# 23          0.9997
# 24          0.0000

# %%
df
# Out:
#                                                  Link  \
# 0   https://dev.to/mechcloud_academy/how-to-integr...
# 1   https://dev.to/tharun_reddy_a193bc1b993b/my-fi...
# 2   https://dev.to/tkuenneth/home-sweet-home-some-...
# 3   https://dev.to/m1rr4/quao-satisfatorio-e-naveg...
# 4   https://dev.to/youlanjihua/uni-appkai-fa-hong-...
# 5   https://dev.to/nad_mc/generic-rag-frameworks-w...
# 6   https://dev.to/youlanjihua/harmonyos-nextshi-z...
# 7   https://dev.to/mayankcse/mastering-ai-context-...
# 8   https://dev.to/githubopensource/bitmagnet-your...
# 9   https://dev.to/youlanjihua/hong-meng-nextshi-z...
# 10  https://dev.to/youlanjihua/harmonyos-nextshi-z...
# 11  https://dev.to/youlanjihua/zai-hong-meng-nextk...
# 12  https://dev.to/youlanjihua/harmonyos-nextkai-f...
# 13  https://dev.to/karoriwal/technical-wealth-the-...
# 14  https://dev.to/youlanjihua/hong-meng-nextkai-f...
# 15  https://dev.to/youlanjihua/harmonyos-nextkai-f...
# 16  https://dev.to/youlanjihua/harmonyos-nextkai-f...
# 17  https://dev.to/youlanjihua/hong-meng-nextkai-f...
# 18  https://dev.to/vrauuss-softwares/how-to-import...
# 19  https://dev.to/youlanjihua/hong-meng-nextkai-f...
# 20  https://dev.to/youlanjihua/harmonyos-nextkai-f...
# 21  https://dev.to/youlanjihua/hong-meng-nextkai-f...
# 22  https://dev.to/aws-builders/diy-building-a-cos...
# 23  https://dev.to/lynxfelony1/making-an-effective...
# 24  https://dev.to/youlanjihua/zai-hong-meng-nextz...
#
#                                                 Title         Time Uploaded  \
# 0   How to integrate hCaptcha into a vuejs applica...  2025-03-23T13:30:00Z
# 1   My First AWS EC2 Instance: From Stumbles to a ...  2025-03-23T13:29:52Z
# 2     Home sweet home: some thoughts on storing files  2025-03-23T13:28:19Z
# 3   quão satisfatório é navegar hierarquicamente s...  2025-03-23T13:27:20Z
# 4                                   uni-app开发鸿蒙应用实操分享  2025-03-23T13:26:02Z
# 5     Generic RAG Frameworks: Why They Can’t Catch On  2025-03-23T13:24:49Z
# 6                       HarmonyOS NEXT实战教程-实现Keep运动轨迹  2025-03-23T13:23:09Z
# 7   Mastering AI Context: How MCP Transforms Conve...  2025-03-23T13:19:14Z
# 8      Bitmagnet: Your Self-Hosted Torrent Powerhouse  2025-03-23T13:19:05Z
# 9                                    鸿蒙NEXT实战教程：音乐播放器  2025-03-23T13:18:40Z
# 7   We've all been there—you ask an AI assistant a...         360  Positive
# 8   Bitmagnet is a self-hosted BitTorrent indexer ...         411  Positive
# 9   上次写过一次鸿蒙的音乐项目，不过是基于api9，最近幽蓝君把它完善优化，并适配到api 12...          16   Neutral
# 10  随着鸿蒙系统5.0的发布，兼容的机型越来越多，对于开发者来说机会也越来越多，大家不要气馁，学...          11   Neutral
# 11  鸿蒙系统发布以后都不知道叫它5.0版本还是NEXT版本了，哈哈，反正是最新版本就对了。\n对...           8   Neutral
# 12  今天的内容是介绍在鸿蒙开发中从相册选择照片，和调用相机拍照，并使用这两个功能实现朋友圈编辑页...           7   Neutral
# 13  The first in a series on how engineering leade...         454  Positive
# 14  今天的实战教程是简单模仿一下抖音短视频，主要是首页部分的内容，先看效果图:  下面为大家讲解...          12   Neutral
# 15  这是之前写过的一个项目，后来删掉了，现在适配到api12重新发布，友友们按需查阅。 本文主要...           9   Neutral
# 16  今天忙里偷闲，分享一个搜索页实现过程，先上效果图：  界面部分比较简单，大体分为导航栏、历史...           6   Neutral
# 17  幽蓝君最近发现小红书是个好东西，一定要多逛 今天就浅浅模仿一下小红书app，主要是底部tab...           6   Neutral
# 18   This plugin transforms SVG files into React c...          12   Neutral
# 19  今天跟大家分享一个ocr文字识别的小项目：  鸿蒙系统提供了文字识别的能力，支持简体中文、英...           6   Neutral
# 20  一早醒来Mate70上热搜了，余承东发文宣布Mate70要在本月发布，史上最强手机终于要来了...          12   Neutral
# 21  昨天Mate70的官方预热直接引起网络爆炸，现在预约人数已经两百多万了，大家都这么有米吗 今...          10   Neutral
# 22   Security questionnaires are very common today...         367  Positive
# 23  The complexity of contemporary software develo...         985  Positive
# 24  本项目是基于api12开发的2048游戏，游戏的逻辑是当用户向某个方向滑动时，将该方向相邻且...           9   Neutral
#
#     Compound Score
# 0          -0.8911
# 1           0.9801
# 2           0.9970
# 3          -0.6808
# 4           0.0000
# 5           0.9984
# 6           0.0000
# 7           0.9714
# 8           0.9978
# 9           0.0000
# 10          0.0000
# 11          0.0000
# 12          0.0000
# 13          0.9990
# 14          0.0000
# 15          0.0000
# 16          0.0000
# 17          0.0000
# 18          0.0000
# 19          0.0000
# 20          0.0000
# 21          0.0000
# 22          0.9940
# 23          0.9997
# 24          0.0000

# %%
#Iterate through each column name.
#Convert the column name to lowercase.
#Replace any spaces in the column name with underscores (_).
#Example: "Time Uploaded" becomes "time_uploaded".
#Access the "reading_time" column.
#For each value in the column, remove the string " min read" from the end.
#Ensure that the remaining value in the column is converted to the appropriate datatype, probably an integer.
#Access the "article_content" column.
#For each value in the column, replace all occurrences of the newline character (\n) with an empty string ("").

df.columns=[x.lower() for x in df.columns] # this methodis called list comprehension
df.columns=[x.replace(' ','_') for x in df.columns] 
df['reading_time']=df['reading_time'].str.replace(' min read','')
df['article_content']=df['article_content'].str.replace('\n','')

df
# Out:
#                                                  link  \
# 0   https://dev.to/mechcloud_academy/how-to-integr...
# 1   https://dev.to/tharun_reddy_a193bc1b993b/my-fi...
# 2   https://dev.to/tkuenneth/home-sweet-home-some-...
# 3   https://dev.to/m1rr4/quao-satisfatorio-e-naveg...
# 4   https://dev.to/youlanjihua/uni-appkai-fa-hong-...
# 5   https://dev.to/nad_mc/generic-rag-frameworks-w...
# 6   https://dev.to/youlanjihua/harmonyos-nextshi-z...
#
# 24                                在鸿蒙NEXT中开发一个2048小游戏  2025-03-23T12:55:48Z
#
#                author                                 tags reading_time  \
# 0    Shailendra Singh      #vue#javascript#frontend#webdev            4
# 1        Tharun Reddy              #devops#cloud#linux#aws            2
# 2      Thomas Künneth                      #kotlin#cmp#kmp            5
# 3               m1rr4                                                 2
# 4           wei chang                                                 1
# 5               MCnad            #showdev#webdev#rag#genai            5
# 6           wei chang                                                 2
# 7        Mayank Gupta  #mcp#ai#machinelearning#programming            4
# 8    GitHubOpenSource      #bittorrent#indexer#dht#graphql            3
# 9           wei chang                                                 2
# 10          wei chang                                                 1
# 11          wei chang                                                 2
# 12          wei chang                                                 2
# 13            Ashwani           #cto#tooling#buildinpublic            4
# 14          wei chang                                                 1
# 15          wei chang                                                 2
# 16          wei chang                                                 2
# 17          wei chang                                                 2
# 18  vrauuss softwares                                                 2
# 19          wei chang                                                 2
# 20          wei chang                                                 3
# 21          wei chang                                                 1
# 22       Adan Alvarez                    #aws#security#rag            3
# 23         Smart Mohr                                                 6
# 24          wei chang                                                 2
#
#                                       article_content  word_count sentiment  \
# 0   A few days back I was trying to integrate hCap...         476  Negative
# 1   Starting my DevOps journey, I set out to launc...         152  Positive
# 2   This is the second article in a series of tips...         632  Positive
# 3   Quando manipulamos o DOM (Document Object Mode...         286  Negative
# 4   上次写过一篇使用uni-app开发鸿蒙的文章，但是当时幽蓝君的编译器还没有编译到鸿蒙的选项，...          20   Neutral
# 5   In the market for generic RAG frameworks, the ...         865  Positive
# 6   幽蓝君前几日收到了华为的邀请，正式加入鸿蒙生态。今天开始会和大家分享HarmonyOS NE...          43   Neutral
# 7   We've all been there—you ask an AI assistant a...         360  Positive
# 8   Bitmagnet is a self-hosted BitTorrent indexer ...         411  Positive
# 9   上次写过一次鸿蒙的音乐项目，不过是基于api9，最近幽蓝君把它完善优化，并适配到api 12...          16   Neutral
# 10  随着鸿蒙系统5.0的发布，兼容的机型越来越多，对于开发者来说机会也越来越多，大家不要气馁，学...          11   Neutral
# 11  鸿蒙系统发布以后都不知道叫它5.0版本还是NEXT版本了，哈哈，反正是最新版本就对了。对于语...           8   Neutral
# 12  今天的内容是介绍在鸿蒙开发中从相册选择照片，和调用相机拍照，并使用这两个功能实现朋友圈编辑页...           7   Neutral
# 13  The first in a series on how engineering leade...         454  Positive
# 14  今天的实战教程是简单模仿一下抖音短视频，主要是首页部分的内容，先看效果图:  下面为大家讲解...          12   Neutral
# 15  这是之前写过的一个项目，后来删掉了，现在适配到api12重新发布，友友们按需查阅。 本文主要...           9   Neutral
# 16  今天忙里偷闲，分享一个搜索页实现过程，先上效果图：  界面部分比较简单，大体分为导航栏、历史...           6   Neutral
# 17  幽蓝君最近发现小红书是个好东西，一定要多逛 今天就浅浅模仿一下小红书app，主要是底部tab...           6   Neutral
# 18   This plugin transforms SVG files into React c...          12   Neutral
# 19  今天跟大家分享一个ocr文字识别的小项目：  鸿蒙系统提供了文字识别的能力，支持简体中文、英...           6   Neutral
# 20  一早醒来Mate70上热搜了，余承东发文宣布Mate70要在本月发布，史上最强手机终于要来了...          12   Neutral
# 21  昨天Mate70的官方预热直接引起网络爆炸，现在预约人数已经两百多万了，大家都这么有米吗 今...          10   Neutral
# 22   Security questionnaires are very common today...         367  Positive
# 23  The complexity of contemporary software develo...         985  Positive
# 24  本项目是基于api12开发的2048游戏，游戏的逻辑是当用户向某个方向滑动时，将该方向相邻且...           9   Neutral
#
#     compound_score
# 0          -0.8911
# 1           0.9801
# 2           0.9970
# 3          -0.6808
# 4           0.0000
# 5           0.9984
# 6           0.0000
# 7           0.9714
# 8           0.9978
# 9           0.0000
# 10          0.0000
# 11          0.0000
# 12          0.0000
# 13          0.9990
# 14          0.0000
# 15          0.0000
# 16          0.0000
# 17          0.0000
# 18          0.0000
# 19          0.0000
# 20          0.0000
# 21          0.0000
# 22          0.9940
# 23          0.9997
# 24          0.0000

# %%
#After the transformations, ensure that each column has the correct data type (e.g., integer, string, date, etc.).
 #You might need to use Pandas functions like astype() to enforce these data types.
#Determine the appropriate data types for each column based on the data that it contains.

import pandas as pd
df = df.astype({
    'link': 'string',
    'title': 'string',
    'time_uploaded': 'string',  # Can be converted to datetime later
    'author': 'string',
    'tags': 'string',
    'reading_time': 'int64',
    'article_content': 'string',
    'word_count': 'int64',
    'sentiment': 'string',
    'compound_score': 'float64'
})


df['time_uploaded'] = pd.to_datetime(df['time_uploaded'])
df
# Out:
#                                                  link  \
# 0   https://dev.to/mechcloud_academy/how-to-integr...
# 1   https://dev.to/tharun_reddy_a193bc1b993b/my-fi...
# 2   https://dev.to/tkuenneth/home-sweet-home-some-...
# 3   https://dev.to/m1rr4/quao-satisfatorio-e-naveg...
# 4   https://dev.to/youlanjihua/uni-appkai-fa-hong-...
# 5   https://dev.to/nad_mc/generic-rag-frameworks-w...
# 6   https://dev.to/youlanjihua/harmonyos-nextshi-z...
# 7   https://dev.to/mayankcse/mastering-ai-context-...
# 8   https://dev.to/githubopensource/bitmagnet-your...
# 9   https://dev.to/youlanjihua/hong-meng-nextshi-z...
# 10  https://dev.to/youlanjihua/harmonyos-nextshi-z...
# 11  https://dev.to/youlanjihua/zai-hong-meng-nextk...
# 12  https://dev.to/youlanjihua/harmonyos-nextkai-f...
# 13  https://dev.to/karoriwal/technical-wealth-the-...
# 14  https://dev.to/youlanjihua/hong-meng-nextkai-f...
# 15  https://dev.to/youlanjihua/harmonyos-nextkai-f...
# 16  https://dev.to/youlanjihua/harmonyos-nextkai-f...
# 17  https://dev.to/youlanjihua/hong-meng-nextkai-f...
# 18  https://dev.to/vrauuss-softwares/how-to-import...
# 19  https://dev.to/youlanjihua/hong-meng-nextkai-f...
# 20  https://dev.to/youlanjihua/harmonyos-nextkai-f...
# 21  https://dev.to/youlanjihua/hong-meng-nextkai-f...
# 22  https://dev.to/aws-builders/diy-building-a-cos...
# 23  https://dev.to/lynxfelony1/making-an-effective...
# 24  https://dev.to/youlanjihua/zai-hong-meng-nextz...
#
#                                                 title  \
# 0   How to integrate hCaptcha into a vuejs applica...
# 1   My First AWS EC2 Instance: From Stumbles to a ...
# 2     Home sweet home: some thoughts on storing files
# 3   quão satisfatório é navegar hierarquicamente s...
# 4                                   uni-app开发鸿蒙应用实操分享
# 5     Generic RAG Frameworks: Why They Can’t Catch On
# 6                       HarmonyOS NEXT实战教程-实现Keep运动轨迹
# 7   Mastering AI Context: How MCP Transforms Conve...
# 15                                                  2
# 16                                                  2
# 17                                                  2
# 18                                                  2
# 19                                                  2
# 20                                                  3
# 21                                                  1
# 22                    #aws#security#rag             3
# 23                                                  6
# 24                                                  2
#
#                                       article_content  word_count sentiment  \
# 0   A few days back I was trying to integrate hCap...         476  Negative
# 1   Starting my DevOps journey, I set out to launc...         152  Positive
# 2   This is the second article in a series of tips...         632  Positive
# 3   Quando manipulamos o DOM (Document Object Mode...         286  Negative
# 4   上次写过一篇使用uni-app开发鸿蒙的文章，但是当时幽蓝君的编译器还没有编译到鸿蒙的选项，...          20   Neutral
# 5   In the market for generic RAG frameworks, the ...         865  Positive
# 6   幽蓝君前几日收到了华为的邀请，正式加入鸿蒙生态。今天开始会和大家分享HarmonyOS NE...          43   Neutral
# 7   We've all been there—you ask an AI assistant a...         360  Positive
# 8   Bitmagnet is a self-hosted BitTorrent indexer ...         411  Positive
# 9   上次写过一次鸿蒙的音乐项目，不过是基于api9，最近幽蓝君把它完善优化，并适配到api 12...          16   Neutral
# 10  随着鸿蒙系统5.0的发布，兼容的机型越来越多，对于开发者来说机会也越来越多，大家不要气馁，学...          11   Neutral
# 11  鸿蒙系统发布以后都不知道叫它5.0版本还是NEXT版本了，哈哈，反正是最新版本就对了。对于语...           8   Neutral
# 12  今天的内容是介绍在鸿蒙开发中从相册选择照片，和调用相机拍照，并使用这两个功能实现朋友圈编辑页...           7   Neutral
# 13  The first in a series on how engineering leade...         454  Positive
# 14  今天的实战教程是简单模仿一下抖音短视频，主要是首页部分的内容，先看效果图:  下面为大家讲解...          12   Neutral
# 15  这是之前写过的一个项目，后来删掉了，现在适配到api12重新发布，友友们按需查阅。 本文主要...           9   Neutral
# 16  今天忙里偷闲，分享一个搜索页实现过程，先上效果图：  界面部分比较简单，大体分为导航栏、历史...           6   Neutral
# 17  幽蓝君最近发现小红书是个好东西，一定要多逛 今天就浅浅模仿一下小红书app，主要是底部tab...           6   Neutral
# 18   This plugin transforms SVG files into React c...          12   Neutral
# 19  今天跟大家分享一个ocr文字识别的小项目：  鸿蒙系统提供了文字识别的能力，支持简体中文、英...           6   Neutral
# 20  一早醒来Mate70上热搜了，余承东发文宣布Mate70要在本月发布，史上最强手机终于要来了...          12   Neutral
# 21  昨天Mate70的官方预热直接引起网络爆炸，现在预约人数已经两百多万了，大家都这么有米吗 今...          10   Neutral
# 22   Security questionnaires are very common today...         367  Positive
# 23  The complexity of contemporary software develo...         985  Positive
# 24  本项目是基于api12开发的2048游戏，游戏的逻辑是当用户向某个方向滑动时，将该方向相邻且...           9   Neutral
#
#     compound_score
# 0          -0.8911
# 1           0.9801
# 2           0.9970
# 3          -0.6808
# 4           0.0000
# 5           0.9984
# 6           0.0000
# 7           0.9714
# 8           0.9978
# 9           0.0000
# 10          0.0000
# 11          0.0000
# 12          0.0000
# 13          0.9990
# 14          0.0000
# 15          0.0000
# 16          0.0000
# 17          0.0000
# 18          0.0000
# 19          0.0000
# 20          0.0000
# 21          0.0000
# 22          0.9940
# 23          0.9997
# 24          0.0000

# %%
df
# Out:
#                                                  link  \
# 0   https://dev.to/mechcloud_academy/how-to-integr...
# 1   https://dev.to/tharun_reddy_a193bc1b993b/my-fi...
# 2   https://dev.to/tkuenneth/home-sweet-home-some-...
# 3   https://dev.to/m1rr4/quao-satisfatorio-e-naveg...
# 4   https://dev.to/youlanjihua/uni-appkai-fa-hong-...
# 5   https://dev.to/nad_mc/generic-rag-frameworks-w...
# 6   https://dev.to/youlanjihua/harmonyos-nextshi-z...
# 7   https://dev.to/mayankcse/mastering-ai-context-...
# 8   https://dev.to/githubopensource/bitmagnet-your...
# 9   https://dev.to/youlanjihua/hong-meng-nextshi-z...
# 10  https://dev.to/youlanjihua/harmonyos-nextshi-z...
# 11  https://dev.to/youlanjihua/zai-hong-meng-nextk...
# 12  https://dev.to/youlanjihua/harmonyos-nextkai-f...
# 13  https://dev.to/karoriwal/technical-wealth-the-...
# 14  https://dev.to/youlanjihua/hong-meng-nextkai-f...
# 15  https://dev.to/youlanjihua/harmonyos-nextkai-f...
# 16  https://dev.to/youlanjihua/harmonyos-nextkai-f...
# 17  https://dev.to/youlanjihua/hong-meng-nextkai-f...
# 18  https://dev.to/vrauuss-softwares/how-to-import...
# 19  https://dev.to/youlanjihua/hong-meng-nextkai-f...
# 20  https://dev.to/youlanjihua/harmonyos-nextkai-f...
# 21  https://dev.to/youlanjihua/hong-meng-nextkai-f...
# 22  https://dev.to/aws-builders/diy-building-a-cos...
# 23  https://dev.to/lynxfelony1/making-an-effective...
# 24  https://dev.to/youlanjihua/zai-hong-meng-nextz...
#
#                                                 title  \
# 0   How to integrate hCaptcha into a vuejs applica...
# 1   My First AWS EC2 Instance: From Stumbles to a ...
# 2     Home sweet home: some thoughts on storing files
# 3   quão satisfatório é navegar hierarquicamente s...
# 4                                   uni-app开发鸿蒙应用实操分享
# 5     Generic RAG Frameworks: Why They Can’t Catch On
# 6                       HarmonyOS NEXT实战教程-实现Keep运动轨迹
# 7   Mastering AI Context: How MCP Transforms Conve...
# 8      Bitmagnet: Your Self-Hosted Torrent Powerhouse
# 9                                    鸿蒙NEXT实战教程：音乐播放器
# 10                           HarmonyOS NEXT实战教程：菜谱App
# 11                               在鸿蒙NEXT开发中实现一个语音识别组件
# 12                       HarmonyOS NEXT开发实战教程：选择相册和拍照
# 13  Technical Wealth: The CTO’s Hidden Advantage i...
# 14                                鸿蒙NEXT开发实战教程：仿抖音短视频
# 15                           HarmonyOS NEXT开发实战案例--圆盘
# 16                           HarmonyOS NEXT开发实战教程—搜索页
# 17                                鸿蒙NEXT开发实战教程—小红书app
# 18  How to import SVG as React Component with Vite...
# 19                                  鸿蒙NEXT开发实战教程—文字识别
# 20                       HarmonyOS NEXT开发实战教程：聊天交友App
# 21                                鸿蒙Next开发实战教程--银行App
# 22  DIY — Building a Cost-Effective Questionnaire ...
# 23  Making an Effective Application Security Progr...
# 24                                在鸿蒙NEXT中开发一个2048小游戏
#
#                time_uploaded             author  \
# 0  2025-03-23 13:30:00+00:00   Shailendra Singh
# 1  2025-03-23 13:29:52+00:00       Tharun Reddy
# 2  2025-03-23 13:28:19+00:00     Thomas Künneth
# 3  2025-03-23 13:27:20+00:00              m1rr4
# 4  2025-03-23 13:26:02+00:00          wei chang
# 5  2025-03-23 13:24:49+00:00              MCnad
# 6  2025-03-23 13:23:09+00:00          wei chang
# 7  2025-03-23 13:19:14+00:00       Mayank Gupta
# 8  2025-03-23 13:19:05+00:00   GitHubOpenSource
# 9  2025-03-23 13:18:40+00:00          wei chang
# 10 2025-03-23 13:15:28+00:00          wei chang
# 11 2025-03-23 13:12:45+00:00          wei chang
# 12 2025-03-23 13:11:06+00:00          wei chang
# 13 2025-03-23 13:09:55+00:00            Ashwani
# 14 2025-03-23 13:09:38+00:00          wei chang
# 15 2025-03-23 13:07:46+00:00          wei chang
# 16 2025-03-23 13:04:35+00:00          wei chang
# 17 2025-03-23 13:03:01+00:00          wei chang
# 18 2025-03-23 13:01:17+00:00  vrauuss softwares
# 19 2025-03-23 13:00:37+00:00          wei chang
# 20 2025-03-23 12:59:18+00:00          wei chang
# 21 2025-03-23 12:57:26+00:00          wei chang
# 22 2025-03-23 12:56:34+00:00       Adan Alvarez
# 23 2025-03-23 12:56:11+00:00         Smart Mohr
# 24 2025-03-23 12:55:48+00:00          wei chang
#
#                                    tags  reading_time  \
# 0       #vue#javascript#frontend#webdev             4
# 1               #devops#cloud#linux#aws             2
# 2                       #kotlin#cmp#kmp             5
# 3                                                   2
# 4                                                   1
# 5             #showdev#webdev#rag#genai             5
# 6                                                   2
# 7   #mcp#ai#machinelearning#programming             4
# 8       #bittorrent#indexer#dht#graphql             3
# 9                                                   2
# 10                                                  1
# 11                                                  2
# 12                                                  2
# 13           #cto#tooling#buildinpublic             4
# 14                                                  1
# 15                                                  2
# 16                                                  2
# 17                                                  2
# 18                                                  2
# 19                                                  2
# 20                                                  3
# 21                                                  1
# 22                    #aws#security#rag             3
# 23                                                  6
# 24                                                  2
#
#                                       article_content  word_count sentiment  \
# 0   A few days back I was trying to integrate hCap...         476  Negative
# 1   Starting my DevOps journey, I set out to launc...         152  Positive
# 2   This is the second article in a series of tips...         632  Positive
# 3   Quando manipulamos o DOM (Document Object Mode...         286  Negative
# 4   上次写过一篇使用uni-app开发鸿蒙的文章，但是当时幽蓝君的编译器还没有编译到鸿蒙的选项，...          20   Neutral
# 5   In the market for generic RAG frameworks, the ...         865  Positive
# 6   幽蓝君前几日收到了华为的邀请，正式加入鸿蒙生态。今天开始会和大家分享HarmonyOS NE...          43   Neutral
# 7   We've all been there—you ask an AI assistant a...         360  Positive
# 8   Bitmagnet is a self-hosted BitTorrent indexer ...         411  Positive
# 9   上次写过一次鸿蒙的音乐项目，不过是基于api9，最近幽蓝君把它完善优化，并适配到api 12...          16   Neutral
# 10  随着鸿蒙系统5.0的发布，兼容的机型越来越多，对于开发者来说机会也越来越多，大家不要气馁，学...          11   Neutral
# 11  鸿蒙系统发布以后都不知道叫它5.0版本还是NEXT版本了，哈哈，反正是最新版本就对了。对于语...           8   Neutral
# 12  今天的内容是介绍在鸿蒙开发中从相册选择照片，和调用相机拍照，并使用这两个功能实现朋友圈编辑页...           7   Neutral
# 13  The first in a series on how engineering leade...         454  Positive
# 14  今天的实战教程是简单模仿一下抖音短视频，主要是首页部分的内容，先看效果图:  下面为大家讲解...          12   Neutral
# 15  这是之前写过的一个项目，后来删掉了，现在适配到api12重新发布，友友们按需查阅。 本文主要...           9   Neutral
# 16  今天忙里偷闲，分享一个搜索页实现过程，先上效果图：  界面部分比较简单，大体分为导航栏、历史...           6   Neutral
# 17  幽蓝君最近发现小红书是个好东西，一定要多逛 今天就浅浅模仿一下小红书app，主要是底部tab...           6   Neutral
# 18   This plugin transforms SVG files into React c...          12   Neutral
# 19  今天跟大家分享一个ocr文字识别的小项目：  鸿蒙系统提供了文字识别的能力，支持简体中文、英...           6   Neutral
# 20  一早醒来Mate70上热搜了，余承东发文宣布Mate70要在本月发布，史上最强手机终于要来了...          12   Neutral
# 21  昨天Mate70的官方预热直接引起网络爆炸，现在预约人数已经两百多万了，大家都这么有米吗 今...          10   Neutral
# 22   Security questionnaires are very common today...         367  Positive
# 23  The complexity of contemporary software develo...         985  Positive
# 24  本项目是基于api12开发的2048游戏，游戏的逻辑是当用户向某个方向滑动时，将该方向相邻且...           9   Neutral
#
#     compound_score
# 0          -0.8911
# 1           0.9801
# 2           0.9970
# 3          -0.6808
# 4           0.0000
# 5           0.9984
# 6           0.0000
# 7           0.9714
# 8           0.9978
# 9           0.0000
# 10          0.0000
# 11          0.0000
# 12          0.0000
# 13          0.9990
# 14          0.0000
# 15          0.0000
# 16          0.0000
# 17          0.0000
# 18          0.0000
# 19          0.0000
# 20          0.0000
# 21          0.0000
# 22          0.9940
# 23          0.9997
# 24          0.0000

# %%
#Open pgAdmin.
#Create a new server connection using the provided credentials:
#In the connected database, create a new table with your name (e.g., yourname).
#Define the columns with appropriate data types:

#The link column must be defined as the primary key.
#Analyze the transformed data to determine the correct data type for each column.
#Examples of datatypes are: text, integer, timestamp, date.
# Database connection parameters
import os

db_params = {
    "dbname": "postgres",
    "user": "testtech",
    "password":  os.getenv("DB_PASSWORD"),#os.getenv()
    "host": "testtech.postgres.database.azure.com",
    "port": "5432"
}

# %%
#Use the psycopg2 library to connect to the PostgreSQL database from your Python environment.
#Install psycopg2 with pip: pip install psycopg2-binary
#Use the provided credentials to establish the connection.
import psycopg2
import pandas as pd

# Database connection parameters
db_params = {
    "dbname": "postgres",
    "user": "testtech",
    "password": "Your_password",
    "host": "testtech.postgres.database.azure.com",
    "port": "5432"
}


try:
    # Connect to PostgreSQL
    conn = psycopg2.connect(**db_params)
    cursor = conn.cursor()
    
    # SQL Insert Query
    insert_query = """
    INSERT INTO feven (link, title, time_uploaded, author, tags, reading_time, article_content, word_count, sentiment, compound_score)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    ON CONFLICT (link) DO NOTHING;  -- Avoids duplicate primary key errors
    """
    
    # Insert DataFrame records one by one
    for _, row in df.iterrows():
        cursor.execute(insert_query, (
            row['link'], row['title'], row['time_uploaded'], row['author'], row['tags'],
            row['reading_time'], row['article_content'], row['word_count'], row['sentiment'], row['compound_score']
        ))

    # Commit and close
    conn.commit()
    print("Data inserted successfully!")

except Exception as e:
    print("Error:", e)

finally:
    if conn:
        cursor.close()
        conn.close()



#"password": os.getenv("DB_PASSWORD")
# Out:
# Data inserted successfully!
