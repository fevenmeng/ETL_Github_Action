# %%
import pandas as pd
from get_data import get_article_data

df = get_article_data()
print(df)
# Out:
# https://dev.to/latest
# https://dev.to/soram/argo-cd-a-gitops-tool-for-kubernetes-continuous-deployment-3d2k
# https://dev.to/aairom/using-llama-cookbook-text2sql-and-really-impressed-3dl1
# https://dev.to/yeauty/master-audio-extraction-in-three-minutes-elegant-video-to-audio-processing-in-rust-3k0e
# https://dev.to/techie_chief/hello-community-2k33
# https://dev.to/exiadev/la-colaboracion-de-agentes-inteligentes-en-amazon-bedrock-automatizacion-inteligente-y-escalable-59gn
# https://dev.to/aafthab_ali/more-efficient-calculator-in-java-271a
# https://dev.to/abdelhakim_baalla/create-user-friendly-contact-forms-with-html-a-beginners-guide-1bd4
# https://dev.to/ollycare/how-to-fix-psycopg2-modulenotfounderrorusing-aws-lambda-layer-57jo
# https://dev.to/engrsakib/mastering-typescript-data-types-a-complete-guide-275p
# https://dev.to/muhammed_murad_7f6b3df615/kyf-tml-mtjr-mtkml-fy-mern-stack-4i7o
# https://dev.to/dbc2201/breaking-the-leetcode-loop-how-goodharts-law-exposes-the-pitfalls-of-mindless-coding-grinds-26hg
# https://dev.to/jules_mukadi/from-shadow-to-code-my-journey-in-tech-4d0h
# https://dev.to/dnovais/ruby-e-rails-no-mac-m1-sem-dor-de-cabeca-orbstack-mise-e-containers-13md
# https://dev.to/inh_honglng_8f7af70c/why-is-gcp-falling-behind-in-enterprise-adoption-should-you-still-learn-it-162f
# https://dev.to/koyadume/speed-up-kubernetes-operations-with-handy-kubectl-aliases-m9g
# https://dev.to/laikokwui/kendoreact-playground-simple-habit-tracker-app-2op9
# https://dev.to/reinny_kimutai_4b1a5c2da8/moving-data-from-mysql-to-postgresql-n75
# https://dev.to/joinwithken/can-ai-and-blockchain-replace-traditional-systems-5907
# https://dev.to/mark_kitur/migrating-data-from-mysql-to-a-data-warehouse-37a6
# https://dev.to/satsvelke/rootalert-real-time-exception-tracking-alerting-for-net-on-slack-teams-1edh
# https://dev.to/aws-builders/introducing-aws-service-reference-information-mcp-server-15g5
# https://dev.to/vakin_mosa_009/blogging-tools-3l2j
# https://dev.to/madsstoumann/digital-clocks-in-css-3dkg
# https://dev.to/taskframe_team/top-5-wireframing-tools-for-designers-and-developers-3k43
# https://dev.to/okerew/i-added-some-input-loading-functions-for-the-neural-web-2jdn
# [nltk_data] Downloading package stopwords to /home/gitpod/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/gitpod/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/gitpod/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/gitpod/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/gitpod/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
#                                                  Link  \
# 0   https://dev.to/soram/argo-cd-a-gitops-tool-for...
# 1   https://dev.to/aairom/using-llama-cookbook-tex...
# 2   https://dev.to/yeauty/master-audio-extraction-...
# 3    https://dev.to/techie_chief/hello-community-2k33
# 4   https://dev.to/exiadev/la-colaboracion-de-agen...
# 5   https://dev.to/aafthab_ali/more-efficient-calc...
# 6   https://dev.to/abdelhakim_baalla/create-user-f...
# 7   https://dev.to/ollycare/how-to-fix-psycopg2-mo...
# 8   https://dev.to/engrsakib/mastering-typescript-...
# 9   https://dev.to/muhammed_murad_7f6b3df615/kyf-t...
# 10  https://dev.to/dbc2201/breaking-the-leetcode-l...
# 11  https://dev.to/jules_mukadi/from-shadow-to-cod...
# 12  https://dev.to/dnovais/ruby-e-rails-no-mac-m1-...
# 13  https://dev.to/inh_honglng_8f7af70c/why-is-gcp...
# 14  https://dev.to/koyadume/speed-up-kubernetes-op...
# 15  https://dev.to/laikokwui/kendoreact-playground...
# 16  https://dev.to/reinny_kimutai_4b1a5c2da8/movin...
# 17  https://dev.to/joinwithken/can-ai-and-blockcha...
# 18  https://dev.to/mark_kitur/migrating-data-from-...
# 19  https://dev.to/satsvelke/rootalert-real-time-e...
# 20  https://dev.to/aws-builders/introducing-aws-se...
# 21  https://dev.to/vakin_mosa_009/blogging-tools-3l2j
# 22  https://dev.to/madsstoumann/digital-clocks-in-...
# 23  https://dev.to/taskframe_team/top-5-wireframin...
# 24  https://dev.to/okerew/i-added-some-input-loadi...
#
#                                                 Title         Time Uploaded  \
# 0   "Argo CD: A GitOps Tool for Kubernetes Continu...  2025-03-22T14:56:56Z
# 1   Using llama-cookbook “Text2SQL” and really imp...  2025-03-22T15:18:10Z
# 2   Master Audio Extraction in Three Minutes | Ele...  2025-03-22T15:13:01Z
# 3                                     Hello Community  2025-03-22T14:59:08Z
# 4   La Colaboración de Agentes Inteligentes en Ama...  2025-03-22T14:56:27Z
# 5                   more efficient Calculator in Java  2025-03-22T14:50:57Z
# 6   Create User-Friendly Contact Forms with HTML: ...  2025-03-22T14:50:05Z
# 7   How to Fix Psycopg2 ‘ModuleNotFoundError’:Usin...  2025-03-22T14:49:27Z
# 8   Mastering TypeScript Data Types: A Complete Guide  2025-03-22T14:47:00Z
# 9                  كيف تعمل متجر متكامل في MERN STACK  2025-03-22T14:41:41Z
# 10  Breaking the LeetCode Loop: How Goodhart’s Law...  2025-03-22T14:35:04Z
# 11            From Shadow to Code: My Journey in Tech  2025-03-22T14:33:23Z
# 12  Ruby e Rails no Mac M1 sem Dor de Cabeça: OrbS...  2025-03-22T14:32:10Z
# 13  Why Is GCP Falling Behind in Enterprise Adopti...  2025-03-22T14:31:16Z
# 14  Speed Up Kubernetes Operations with Handy Kube...  2025-03-22T14:30:00Z
# 15   KendoReact Playground - Simple Habit Tracker App  2025-03-22T14:16:02Z
# 16               Moving data from mysql to postgresql  2025-03-22T14:13:20Z
# 17  Can AI and Blockchain Replace Traditional Syst...  2025-03-22T14:00:52Z
# 18      Migrating Data from MySQL to a Data Warehouse  2025-03-22T14:00:22Z
# 19  🚀 RootAlert - Real-time Exception Tracking & A...  2025-03-22T13:54:26Z
# 20  Introducing AWS Service Reference Information ...  2025-03-22T13:47:45Z
# 21                                     Blogging Tools  2025-03-22T13:46:36Z
# 22                              Digital Clocks in CSS  2025-03-22T13:44:35Z
# 23  Top 5 Wireframing Tools for Designers and Deve...  2025-03-22T13:40:41Z
# 24  I added some input loading functions for the n...  2025-03-22T13:32:16Z
#
#                Author                                               Tags  \
# 0         Soram Varma                   #gitops#argocd#kubernetes#devops
# 1         Alain Airom                        #meta#llm#text2sql#cookbook
# 2           Yeauty YE                                #rust#ffmpeg#encode
# 3        Techie Chief                                       #emptystring
# 4    Orland Contreras                 #aiagents#aws#amazonbedrock#agents
# 5   Aafthab Ali Shaik           #java#beginners#programming#productivity
# 6   Abdelhakim Baalla                       #html#css#frontend#beginners
# 7        Yusuf Ishola                    #aws#lambda#serverless#postgres
# 8     Md Nazmus Sakib                #programming#typescript#webdev#web3
# 9      Muhammed Murad                      #react#aws#typescript#mongodb
# 10            dbc2201  #leetcode#codinginterviews#softwareengineering...
# 11       Jules MUKADI                   #devchallenge#wecoded#dei#career
# 12       Diego Novais
# 13   Đinh Hoàng Lương                                  #gcp#aws#azure#ai
# 14   Shailendra Singh                                 #devops#kubernetes
# 15        Lai Kok Wui     #devchallenge#kendoreactchallenge#react#webdev
# 16     reinny kimutai
# 17              Kevin                      #techtalks#ai#web3#blockchain
# 18         Mark Kitur                                          #luxdevhq
# 19       Satish Patil                    #dotnet#csharp#monitoring#slack
# 20        Paul SANTUS                                 #aws#genai#mcp#iam
# 21          Vikomosam                                       #programming
# 22      Mads Stoumann                     #showdev#webdev#css#javascript
# 23          TaskFrame                #wireframes#uiux#design#designtools
# 24             Okerew        #ai#architecture#machinelearning#algorithms
#
#    Reading Time                                    Article Content  \
# 0    4 min read  Introduction In modern DevOps practices, ensur...
# 1    5 min read  My experience trying ‘Text2SQL’ recipe from ll...
# 2    4 min read  In multimedia development, extracting audio fr...
# 3    1 min read                    This is my first post at dev.to
# 4    2 min read  La inteligencia artificial está entrando en un...
# 5    1 min read                                       the code!!\n
# 6    9 min read   Have you ever wondered how websites collect v...
# 7    3 min read   The psycopg2 module is a PostgreSQL adapter f...
# 8    2 min read  TypeScript introduces a powerful type system o...
# 9    3 min read  هذا مثال لبنية مقالة متكاملة حول الموضوع المطل...
# 10   3 min read  Introduction: The Coding Olympiad Obsession\nW...
# 11   2 min read  This is a submission for the : Echoes of Exper...
# 12   3 min read  O OrbStack é um ambiente leve para rodar Docke...
# 13   3 min read  AWS and Azure do lead in enterprise adoption. ...
# 14   3 min read  Typing more is good if you are trying to expla...
# 15   2 min read  This is a submission for the . This is my revi...
# 16   1 min read  Precise Steps to Transfer Data from MySQL to P...
# 17   4 min read  Technology is evolving at an unprecedented pac...
# 18   1 min read  Why Migrate? MySQL is great for transactions b...
# 19   3 min read   🔍 Tired of missing critical exceptions in you...
# 20   2 min read  LLMs are like genies trapped in a bottle: thei...
# 21   3 min read  Here are several free alternatives to Substack...
# 22   6 min read  In my previous post, I looked into , mimicking...
# 23   3 min read  Wireframing is a crucial step in UI/UX design ...
# 24   1 min read  I added some input loading functions for the n...
#
#     Word Count Sentiment  Compound Score
# 0          530  Positive          0.9943
# 1          241  Positive          0.9074
# 2          502  Positive          0.9938
# 3            3   Neutral          0.0000
# 4          335  Negative         -0.4404
# 5            3   Neutral          0.0000
# 6          496  Positive          0.9985
# 7          352  Positive          0.9827
# 8          100  Positive          0.9513
# 9           44   Neutral          0.0000
# 10         321  Positive          0.9609
# 11         289  Positive          0.9908
# 12         405  Negative         -0.9558
# 13         636  Positive          0.9981
# 14         378  Positive          0.9876
# 15         134  Positive          0.9645
# 16          39   Neutral          0.0000
# 17         704  Positive          0.9961
# 18          91  Positive          0.9852
# 19         243  Positive          0.9007
# 20         243  Positive          0.9312
# 21         401  Positive          0.9992
# 22         525  Positive          0.9862
# 23         493  Positive          0.9976
# 24           6   Neutral          0.0000

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
#Iterate through each column name.
#Convert the column name to lowercase.
#Replace any spaces in the column name with underscores (_).
#Example: "Time Uploaded" becomes "time_uploaded".
#Access the "reading_time" column.
#For each value in the column, remove the string " min read" from the end.
#Ensure that the remaining value in the column is converted to the appropriate datatype, probably an integer.
#Access the "article_content" column.
#For each value in the column, replace all occurrences of the newline character (\n) with an empty string ("").

df.columns=[x.lower() for x in df.columns] # this methodis called list comprehension
df.columns=[x.replace(' ','_') for x in df.columns] 
df['reading_time']=df['reading_time'].str.replace(' min read','')
df['article_content']=df['article_content'].str.replace('\n','')

df
# Out:
#                                                  link  \
# 0   https://dev.to/soram/argo-cd-a-gitops-tool-for...
# 1   https://dev.to/aairom/using-llama-cookbook-tex...
# 2   https://dev.to/yeauty/master-audio-extraction-...
# 3    https://dev.to/techie_chief/hello-community-2k33
# 4   https://dev.to/exiadev/la-colaboracion-de-agen...
# 5   https://dev.to/aafthab_ali/more-efficient-calc...
# 6   https://dev.to/abdelhakim_baalla/create-user-f...
# 7   https://dev.to/ollycare/how-to-fix-psycopg2-mo...
# 8   https://dev.to/engrsakib/mastering-typescript-...
# 9   https://dev.to/muhammed_murad_7f6b3df615/kyf-t...
# 10  https://dev.to/dbc2201/breaking-the-leetcode-l...
# 11  https://dev.to/jules_mukadi/from-shadow-to-cod...
# 12  https://dev.to/dnovais/ruby-e-rails-no-mac-m1-...
# 13  https://dev.to/inh_honglng_8f7af70c/why-is-gcp...
# 14  https://dev.to/koyadume/speed-up-kubernetes-op...
# 15  https://dev.to/laikokwui/kendoreact-playground...
# 16  https://dev.to/reinny_kimutai_4b1a5c2da8/movin...
# 17  https://dev.to/joinwithken/can-ai-and-blockcha...
# 18  https://dev.to/mark_kitur/migrating-data-from-...
# 19  https://dev.to/satsvelke/rootalert-real-time-e...
# 20  https://dev.to/aws-builders/introducing-aws-se...
# 21  https://dev.to/vakin_mosa_009/blogging-tools-3l2j
# 22  https://dev.to/madsstoumann/digital-clocks-in-...
# 23  https://dev.to/taskframe_team/top-5-wireframin...
# 24  https://dev.to/okerew/i-added-some-input-loadi...
#
#                                                 title         time_uploaded  \
# 0   "Argo CD: A GitOps Tool for Kubernetes Continu...  2025-03-22T14:56:56Z
# 1   Using llama-cookbook “Text2SQL” and really imp...  2025-03-22T15:18:10Z
# 2   Master Audio Extraction in Three Minutes | Ele...  2025-03-22T15:13:01Z
# 3                                     Hello Community  2025-03-22T14:59:08Z
# 4   La Colaboración de Agentes Inteligentes en Ama...  2025-03-22T14:56:27Z
# 5                   more efficient Calculator in Java  2025-03-22T14:50:57Z
# 6   Create User-Friendly Contact Forms with HTML: ...  2025-03-22T14:50:05Z
# 7   How to Fix Psycopg2 ‘ModuleNotFoundError’:Usin...  2025-03-22T14:49:27Z
# 8   Mastering TypeScript Data Types: A Complete Guide  2025-03-22T14:47:00Z
# 9                  كيف تعمل متجر متكامل في MERN STACK  2025-03-22T14:41:41Z
# 10  Breaking the LeetCode Loop: How Goodhart’s Law...  2025-03-22T14:35:04Z
# 11            From Shadow to Code: My Journey in Tech  2025-03-22T14:33:23Z
# 12  Ruby e Rails no Mac M1 sem Dor de Cabeça: OrbS...  2025-03-22T14:32:10Z
# 13  Why Is GCP Falling Behind in Enterprise Adopti...  2025-03-22T14:31:16Z
# 14  Speed Up Kubernetes Operations with Handy Kube...  2025-03-22T14:30:00Z
# 15   KendoReact Playground - Simple Habit Tracker App  2025-03-22T14:16:02Z
# 16               Moving data from mysql to postgresql  2025-03-22T14:13:20Z
# 17  Can AI and Blockchain Replace Traditional Syst...  2025-03-22T14:00:52Z
# 18      Migrating Data from MySQL to a Data Warehouse  2025-03-22T14:00:22Z
# 19  🚀 RootAlert - Real-time Exception Tracking & A...  2025-03-22T13:54:26Z
# 20  Introducing AWS Service Reference Information ...  2025-03-22T13:47:45Z
# 21                                     Blogging Tools  2025-03-22T13:46:36Z
# 22                              Digital Clocks in CSS  2025-03-22T13:44:35Z
# 23  Top 5 Wireframing Tools for Designers and Deve...  2025-03-22T13:40:41Z
# 24  I added some input loading functions for the n...  2025-03-22T13:32:16Z
#
#                author                                               tags  \
# 0         Soram Varma                   #gitops#argocd#kubernetes#devops
# 1         Alain Airom                        #meta#llm#text2sql#cookbook
# 2           Yeauty YE                                #rust#ffmpeg#encode
# 3        Techie Chief                                       #emptystring
# 4    Orland Contreras                 #aiagents#aws#amazonbedrock#agents
# 5   Aafthab Ali Shaik           #java#beginners#programming#productivity
# 6   Abdelhakim Baalla                       #html#css#frontend#beginners
# 7        Yusuf Ishola                    #aws#lambda#serverless#postgres
# 8     Md Nazmus Sakib                #programming#typescript#webdev#web3
# 9      Muhammed Murad                      #react#aws#typescript#mongodb
# 10            dbc2201  #leetcode#codinginterviews#softwareengineering...
# 11       Jules MUKADI                   #devchallenge#wecoded#dei#career
# 12       Diego Novais
# 13   Đinh Hoàng Lương                                  #gcp#aws#azure#ai
# 14   Shailendra Singh                                 #devops#kubernetes
# 15        Lai Kok Wui     #devchallenge#kendoreactchallenge#react#webdev
# 16     reinny kimutai
# 17              Kevin                      #techtalks#ai#web3#blockchain
# 18         Mark Kitur                                          #luxdevhq
# 19       Satish Patil                    #dotnet#csharp#monitoring#slack
# 20        Paul SANTUS                                 #aws#genai#mcp#iam
# 21          Vikomosam                                       #programming
# 22      Mads Stoumann                     #showdev#webdev#css#javascript
# 23          TaskFrame                #wireframes#uiux#design#designtools
# 24             Okerew        #ai#architecture#machinelearning#algorithms
#
#    reading_time                                    article_content  \
# 0             4  Introduction In modern DevOps practices, ensur...
# 1             5  My experience trying ‘Text2SQL’ recipe from ll...
# 2             4  In multimedia development, extracting audio fr...
# 3             1                    This is my first post at dev.to
# 4             2  La inteligencia artificial está entrando en un...
# 5             1                                         the code!!
# 6             9   Have you ever wondered how websites collect v...
# 7             3   The psycopg2 module is a PostgreSQL adapter f...
# 8             2  TypeScript introduces a powerful type system o...
# 9             3  هذا مثال لبنية مقالة متكاملة حول الموضوع المطل...
# 10            3  Introduction: The Coding Olympiad ObsessionWal...
# 11            2  This is a submission for the : Echoes of Exper...
# 12            3  O OrbStack é um ambiente leve para rodar Docke...
# 13            3  AWS and Azure do lead in enterprise adoption. ...
# 14            3  Typing more is good if you are trying to expla...
# 15            2  This is a submission for the . This is my revi...
# 16            1  Precise Steps to Transfer Data from MySQL to P...
# 17            4  Technology is evolving at an unprecedented pac...
# 18            1  Why Migrate? MySQL is great for transactions b...
# 19            3   🔍 Tired of missing critical exceptions in you...
# 20            2  LLMs are like genies trapped in a bottle: thei...
# 21            3  Here are several free alternatives to Substack...
# 22            6  In my previous post, I looked into , mimicking...
# 23            3  Wireframing is a crucial step in UI/UX design ...
# 24            1  I added some input loading functions for the n...
#
#     word_count sentiment  compound_score
# 0          530  Positive          0.9943
# 1          241  Positive          0.9074
# 2          502  Positive          0.9938
# 3            3   Neutral          0.0000
# 4          335  Negative         -0.4404
# 5            3   Neutral          0.0000
# 6          496  Positive          0.9985
# 7          352  Positive          0.9827
# 8          100  Positive          0.9513
# 9           44   Neutral          0.0000
# 10         321  Positive          0.9609
# 11         289  Positive          0.9908
# 12         405  Negative         -0.9558
# 13         636  Positive          0.9981
# 14         378  Positive          0.9876
# 15         134  Positive          0.9645
# 16          39   Neutral          0.0000
# 17         704  Positive          0.9961
# 18          91  Positive          0.9852
# 19         243  Positive          0.9007
# 20         243  Positive          0.9312
# 21         401  Positive          0.9992
# 22         525  Positive          0.9862
# 23         493  Positive          0.9976
# 24           6   Neutral          0.0000

# %%
#After the transformations, ensure that each column has the correct data type (e.g., integer, string, date, etc.).
 #You might need to use Pandas functions like astype() to enforce these data types.
#Determine the appropriate data types for each column based on the data that it contains.

import pandas as pd
df = df.astype({
    'link': 'string',
    'title': 'string',
    'time_uploaded': 'string',  # Can be converted to datetime later
    'author': 'string',
    'tags': 'string',
    'reading_time': 'int64',
    'article_content': 'string',
    'word_count': 'int64',
    'sentiment': 'string',
    'compound_score': 'float64'
})


df['time_uploaded'] = pd.to_datetime(df['time_uploaded'])
df
# Out:
#                                                  link  \
# 0   https://dev.to/soram/argo-cd-a-gitops-tool-for...
# 1   https://dev.to/aairom/using-llama-cookbook-tex...
# 2   https://dev.to/yeauty/master-audio-extraction-...
# 3    https://dev.to/techie_chief/hello-community-2k33
# 4   https://dev.to/exiadev/la-colaboracion-de-agen...
# 5   https://dev.to/aafthab_ali/more-efficient-calc...
# 6   https://dev.to/abdelhakim_baalla/create-user-f...
# 7   https://dev.to/ollycare/how-to-fix-psycopg2-mo...
# 8   https://dev.to/engrsakib/mastering-typescript-...
# 9   https://dev.to/muhammed_murad_7f6b3df615/kyf-t...
# 10  https://dev.to/dbc2201/breaking-the-leetcode-l...
# 11  https://dev.to/jules_mukadi/from-shadow-to-cod...
# 12  https://dev.to/dnovais/ruby-e-rails-no-mac-m1-...
# 13  https://dev.to/inh_honglng_8f7af70c/why-is-gcp...
# 14  https://dev.to/koyadume/speed-up-kubernetes-op...
# 15  https://dev.to/laikokwui/kendoreact-playground...
# 16  https://dev.to/reinny_kimutai_4b1a5c2da8/movin...
# 17  https://dev.to/joinwithken/can-ai-and-blockcha...
# 18  https://dev.to/mark_kitur/migrating-data-from-...
# 19  https://dev.to/satsvelke/rootalert-real-time-e...
# 20  https://dev.to/aws-builders/introducing-aws-se...
# 21  https://dev.to/vakin_mosa_009/blogging-tools-3l2j
# 22  https://dev.to/madsstoumann/digital-clocks-in-...
# 23  https://dev.to/taskframe_team/top-5-wireframin...
# 24  https://dev.to/okerew/i-added-some-input-loadi...
#
#                                                 title  \
# 0   "Argo CD: A GitOps Tool for Kubernetes Continu...
# 1   Using llama-cookbook “Text2SQL” and really imp...
# 2   Master Audio Extraction in Three Minutes | Ele...
# 3                                     Hello Community
# 4   La Colaboración de Agentes Inteligentes en Ama...
# 5                   more efficient Calculator in Java
# 6   Create User-Friendly Contact Forms with HTML: ...
# 7   How to Fix Psycopg2 ‘ModuleNotFoundError’:Usin...
# 8   Mastering TypeScript Data Types: A Complete Guide
# 9                  كيف تعمل متجر متكامل في MERN STACK
# 10  Breaking the LeetCode Loop: How Goodhart’s Law...
# 11            From Shadow to Code: My Journey in Tech
# 12  Ruby e Rails no Mac M1 sem Dor de Cabeça: OrbS...
# 13  Why Is GCP Falling Behind in Enterprise Adopti...
# 14  Speed Up Kubernetes Operations with Handy Kube...
# 15   KendoReact Playground - Simple Habit Tracker App
# 16               Moving data from mysql to postgresql
# 17  Can AI and Blockchain Replace Traditional Syst...
# 18      Migrating Data from MySQL to a Data Warehouse
# 19  🚀 RootAlert - Real-time Exception Tracking & A...
# 20  Introducing AWS Service Reference Information ...
# 21                                     Blogging Tools
# 22                              Digital Clocks in CSS
# 23  Top 5 Wireframing Tools for Designers and Deve...
# 24  I added some input loading functions for the n...
#
#                time_uploaded             author  \
# 0  2025-03-22 14:56:56+00:00        Soram Varma
# 1  2025-03-22 15:18:10+00:00        Alain Airom
# 2  2025-03-22 15:13:01+00:00          Yeauty YE
# 3  2025-03-22 14:59:08+00:00       Techie Chief
# 4  2025-03-22 14:56:27+00:00   Orland Contreras
# 5  2025-03-22 14:50:57+00:00  Aafthab Ali Shaik
# 6  2025-03-22 14:50:05+00:00  Abdelhakim Baalla
# 7  2025-03-22 14:49:27+00:00       Yusuf Ishola
# 8  2025-03-22 14:47:00+00:00    Md Nazmus Sakib
# 9  2025-03-22 14:41:41+00:00     Muhammed Murad
# 10 2025-03-22 14:35:04+00:00            dbc2201
# 11 2025-03-22 14:33:23+00:00       Jules MUKADI
# 12 2025-03-22 14:32:10+00:00       Diego Novais
# 13 2025-03-22 14:31:16+00:00   Đinh Hoàng Lương
# 14 2025-03-22 14:30:00+00:00   Shailendra Singh
# 15 2025-03-22 14:16:02+00:00        Lai Kok Wui
# 16 2025-03-22 14:13:20+00:00     reinny kimutai
# 17 2025-03-22 14:00:52+00:00              Kevin
# 18 2025-03-22 14:00:22+00:00         Mark Kitur
# 19 2025-03-22 13:54:26+00:00       Satish Patil
# 20 2025-03-22 13:47:45+00:00        Paul SANTUS
# 21 2025-03-22 13:46:36+00:00          Vikomosam
# 22 2025-03-22 13:44:35+00:00      Mads Stoumann
# 23 2025-03-22 13:40:41+00:00          TaskFrame
# 24 2025-03-22 13:32:16+00:00             Okerew
#
#                                                  tags  reading_time  \
# 0                    #gitops#argocd#kubernetes#devops             4
# 1                         #meta#llm#text2sql#cookbook             5
# 2                                 #rust#ffmpeg#encode             4
# 3                                        #emptystring             1
# 4                  #aiagents#aws#amazonbedrock#agents             2
# 5            #java#beginners#programming#productivity             1
# 6                        #html#css#frontend#beginners             9
# 7                     #aws#lambda#serverless#postgres             3
# 8                 #programming#typescript#webdev#web3             2
# 9                       #react#aws#typescript#mongodb             3
# 10  #leetcode#codinginterviews#softwareengineering...             3
# 11                   #devchallenge#wecoded#dei#career             2
# 12                                                                3
# 13                                  #gcp#aws#azure#ai             3
# 14                                 #devops#kubernetes             3
# 15     #devchallenge#kendoreactchallenge#react#webdev             2
# 16                                                                1
# 17                      #techtalks#ai#web3#blockchain             4
# 18                                          #luxdevhq             1
# 19                    #dotnet#csharp#monitoring#slack             3
# 20                                 #aws#genai#mcp#iam             2
# 21                                       #programming             3
# 22                     #showdev#webdev#css#javascript             6
# 23                #wireframes#uiux#design#designtools             3
# 24        #ai#architecture#machinelearning#algorithms             1
#
#                                       article_content  word_count sentiment  \
# 0   Introduction In modern DevOps practices, ensur...         530  Positive
# 1   My experience trying ‘Text2SQL’ recipe from ll...         241  Positive
# 2   In multimedia development, extracting audio fr...         502  Positive
# 3                     This is my first post at dev.to           3   Neutral
# 4   La inteligencia artificial está entrando en un...         335  Negative
# 5                                          the code!!           3   Neutral
# 6    Have you ever wondered how websites collect v...         496  Positive
# 7    The psycopg2 module is a PostgreSQL adapter f...         352  Positive
# 8   TypeScript introduces a powerful type system o...         100  Positive
# 9   هذا مثال لبنية مقالة متكاملة حول الموضوع المطل...          44   Neutral
# 10  Introduction: The Coding Olympiad ObsessionWal...         321  Positive
# 11  This is a submission for the : Echoes of Exper...         289  Positive
# 12  O OrbStack é um ambiente leve para rodar Docke...         405  Negative
# 13  AWS and Azure do lead in enterprise adoption. ...         636  Positive
# 14  Typing more is good if you are trying to expla...         378  Positive
# 15  This is a submission for the . This is my revi...         134  Positive
# 16  Precise Steps to Transfer Data from MySQL to P...          39   Neutral
# 17  Technology is evolving at an unprecedented pac...         704  Positive
# 18  Why Migrate? MySQL is great for transactions b...          91  Positive
# 19   🔍 Tired of missing critical exceptions in you...         243  Positive
# 20  LLMs are like genies trapped in a bottle: thei...         243  Positive
# 21  Here are several free alternatives to Substack...         401  Positive
# 22  In my previous post, I looked into , mimicking...         525  Positive
# 23  Wireframing is a crucial step in UI/UX design ...         493  Positive
# 24  I added some input loading functions for the n...           6   Neutral
#
#     compound_score
# 0           0.9943
# 1           0.9074
# 2           0.9938
# 3           0.0000
# 4          -0.4404
# 5           0.0000
# 6           0.9985
# 7           0.9827
# 8           0.9513
# 9           0.0000
# 10          0.9609
# 11          0.9908
# 12         -0.9558
# 13          0.9981
# 14          0.9876
# 15          0.9645
# 16          0.0000
# 17          0.9961
# 18          0.9852
# 19          0.9007
# 20          0.9312
# 21          0.9992
# 22          0.9862
# 23          0.9976
# 24          0.0000

# %%
df
# Out:
#                                                  link  \
# 0   https://dev.to/soram/argo-cd-a-gitops-tool-for...
# 1   https://dev.to/aairom/using-llama-cookbook-tex...
# 2   https://dev.to/yeauty/master-audio-extraction-...
# 3    https://dev.to/techie_chief/hello-community-2k33
# 4   https://dev.to/exiadev/la-colaboracion-de-agen...
# 5   https://dev.to/aafthab_ali/more-efficient-calc...
# 6   https://dev.to/abdelhakim_baalla/create-user-f...
# 7   https://dev.to/ollycare/how-to-fix-psycopg2-mo...
# 8   https://dev.to/engrsakib/mastering-typescript-...
# 9   https://dev.to/muhammed_murad_7f6b3df615/kyf-t...
# 10  https://dev.to/dbc2201/breaking-the-leetcode-l...
# 11  https://dev.to/jules_mukadi/from-shadow-to-cod...
# 12  https://dev.to/dnovais/ruby-e-rails-no-mac-m1-...
# 13  https://dev.to/inh_honglng_8f7af70c/why-is-gcp...
# 14  https://dev.to/koyadume/speed-up-kubernetes-op...
# 15  https://dev.to/laikokwui/kendoreact-playground...
# 16  https://dev.to/reinny_kimutai_4b1a5c2da8/movin...
# 17  https://dev.to/joinwithken/can-ai-and-blockcha...
# 18  https://dev.to/mark_kitur/migrating-data-from-...
# 19  https://dev.to/satsvelke/rootalert-real-time-e...
# 20  https://dev.to/aws-builders/introducing-aws-se...
# 21  https://dev.to/vakin_mosa_009/blogging-tools-3l2j
# 22  https://dev.to/madsstoumann/digital-clocks-in-...
# 23  https://dev.to/taskframe_team/top-5-wireframin...
# 24  https://dev.to/okerew/i-added-some-input-loadi...
#
#                                                 title  \
# 0   "Argo CD: A GitOps Tool for Kubernetes Continu...
# 1   Using llama-cookbook “Text2SQL” and really imp...
# 2   Master Audio Extraction in Three Minutes | Ele...
# 3                                     Hello Community
# 4   La Colaboración de Agentes Inteligentes en Ama...
# 5                   more efficient Calculator in Java
# 6   Create User-Friendly Contact Forms with HTML: ...
# 7   How to Fix Psycopg2 ‘ModuleNotFoundError’:Usin...
# 8   Mastering TypeScript Data Types: A Complete Guide
# 9                  كيف تعمل متجر متكامل في MERN STACK
# 10  Breaking the LeetCode Loop: How Goodhart’s Law...
# 11            From Shadow to Code: My Journey in Tech
# 12  Ruby e Rails no Mac M1 sem Dor de Cabeça: OrbS...
# 13  Why Is GCP Falling Behind in Enterprise Adopti...
# 14  Speed Up Kubernetes Operations with Handy Kube...
# 15   KendoReact Playground - Simple Habit Tracker App
# 16               Moving data from mysql to postgresql
# 17  Can AI and Blockchain Replace Traditional Syst...
# 18      Migrating Data from MySQL to a Data Warehouse
# 19  🚀 RootAlert - Real-time Exception Tracking & A...
# 20  Introducing AWS Service Reference Information ...
# 21                                     Blogging Tools
# 22                              Digital Clocks in CSS
# 23  Top 5 Wireframing Tools for Designers and Deve...
# 24  I added some input loading functions for the n...
#
#                time_uploaded             author  \
# 0  2025-03-22 14:56:56+00:00        Soram Varma
# 1  2025-03-22 15:18:10+00:00        Alain Airom
# 2  2025-03-22 15:13:01+00:00          Yeauty YE
# 3  2025-03-22 14:59:08+00:00       Techie Chief
# 4  2025-03-22 14:56:27+00:00   Orland Contreras
# 5  2025-03-22 14:50:57+00:00  Aafthab Ali Shaik
# 6  2025-03-22 14:50:05+00:00  Abdelhakim Baalla
# 7  2025-03-22 14:49:27+00:00       Yusuf Ishola
# 8  2025-03-22 14:47:00+00:00    Md Nazmus Sakib
# 9  2025-03-22 14:41:41+00:00     Muhammed Murad
# 10 2025-03-22 14:35:04+00:00            dbc2201
# 11 2025-03-22 14:33:23+00:00       Jules MUKADI
# 12 2025-03-22 14:32:10+00:00       Diego Novais
# 13 2025-03-22 14:31:16+00:00   Đinh Hoàng Lương
# 14 2025-03-22 14:30:00+00:00   Shailendra Singh
# 15 2025-03-22 14:16:02+00:00        Lai Kok Wui
# 16 2025-03-22 14:13:20+00:00     reinny kimutai
# 17 2025-03-22 14:00:52+00:00              Kevin
# 18 2025-03-22 14:00:22+00:00         Mark Kitur
# 19 2025-03-22 13:54:26+00:00       Satish Patil
# 20 2025-03-22 13:47:45+00:00        Paul SANTUS
# 21 2025-03-22 13:46:36+00:00          Vikomosam
# 22 2025-03-22 13:44:35+00:00      Mads Stoumann
# 23 2025-03-22 13:40:41+00:00          TaskFrame
# 24 2025-03-22 13:32:16+00:00             Okerew
#
#                                                  tags  reading_time  \
# 0                    #gitops#argocd#kubernetes#devops             4
# 1                         #meta#llm#text2sql#cookbook             5
# 2                                 #rust#ffmpeg#encode             4
# 3                                        #emptystring             1
# 4                  #aiagents#aws#amazonbedrock#agents             2
# 5            #java#beginners#programming#productivity             1
# 6                        #html#css#frontend#beginners             9
# 7                     #aws#lambda#serverless#postgres             3
# 8                 #programming#typescript#webdev#web3             2
# 9                       #react#aws#typescript#mongodb             3
# 10  #leetcode#codinginterviews#softwareengineering...             3
# 11                   #devchallenge#wecoded#dei#career             2
# 12                                                                3
# 13                                  #gcp#aws#azure#ai             3
# 14                                 #devops#kubernetes             3
# 15     #devchallenge#kendoreactchallenge#react#webdev             2
# 16                                                                1
# 17                      #techtalks#ai#web3#blockchain             4
# 18                                          #luxdevhq             1
# 19                    #dotnet#csharp#monitoring#slack             3
# 20                                 #aws#genai#mcp#iam             2
# 21                                       #programming             3
# 22                     #showdev#webdev#css#javascript             6
# 23                #wireframes#uiux#design#designtools             3
# 24        #ai#architecture#machinelearning#algorithms             1
#
#                                       article_content  word_count sentiment  \
# 0   Introduction In modern DevOps practices, ensur...         530  Positive
# 1   My experience trying ‘Text2SQL’ recipe from ll...         241  Positive
# 2   In multimedia development, extracting audio fr...         502  Positive
# 3                     This is my first post at dev.to           3   Neutral
# 4   La inteligencia artificial está entrando en un...         335  Negative
# 5                                          the code!!           3   Neutral
# 6    Have you ever wondered how websites collect v...         496  Positive
# 7    The psycopg2 module is a PostgreSQL adapter f...         352  Positive
# 8   TypeScript introduces a powerful type system o...         100  Positive
# 9   هذا مثال لبنية مقالة متكاملة حول الموضوع المطل...          44   Neutral
# 10  Introduction: The Coding Olympiad ObsessionWal...         321  Positive
# 11  This is a submission for the : Echoes of Exper...         289  Positive
# 12  O OrbStack é um ambiente leve para rodar Docke...         405  Negative
# 13  AWS and Azure do lead in enterprise adoption. ...         636  Positive
# 14  Typing more is good if you are trying to expla...         378  Positive
# 15  This is a submission for the . This is my revi...         134  Positive
# 16  Precise Steps to Transfer Data from MySQL to P...          39   Neutral
# 17  Technology is evolving at an unprecedented pac...         704  Positive
# 18  Why Migrate? MySQL is great for transactions b...          91  Positive
# 19   🔍 Tired of missing critical exceptions in you...         243  Positive
# 20  LLMs are like genies trapped in a bottle: thei...         243  Positive
# 21  Here are several free alternatives to Substack...         401  Positive
# 22  In my previous post, I looked into , mimicking...         525  Positive
# 23  Wireframing is a crucial step in UI/UX design ...         493  Positive
# 24  I added some input loading functions for the n...           6   Neutral
#
#     compound_score
# 0           0.9943
# 1           0.9074
# 2           0.9938
# 3           0.0000
# 4          -0.4404
# 5           0.0000
# 6           0.9985
# 7           0.9827
# 8           0.9513
# 9           0.0000
# 10          0.9609
# 11          0.9908
# 12         -0.9558
# 13          0.9981
# 14          0.9876
# 15          0.9645
# 16          0.0000
# 17          0.9961
# 18          0.9852
# 19          0.9007
# 20          0.9312
# 21          0.9992
# 22          0.9862
# 23          0.9976
# 24          0.0000

# %%
#Open pgAdmin.
#Create a new server connection using the provided credentials:
#In the connected database, create a new table with your name (e.g., yourname).
#Define the columns with appropriate data types:

#The link column must be defined as the primary key.
#Analyze the transformed data to determine the correct data type for each column.
#Examples of datatypes are: text, integer, timestamp, date.
# Database connection parameters
import os

db_params = {
    "dbname": "postgres",
    "user": "testtech",
    "password":  os.getenv("DB_PASSWORD"),#os.getenv()
    "host": "testtech.postgres.database.azure.com",
    "port": "5432"
}

# %%
#Use the psycopg2 library to connect to the PostgreSQL database from your Python environment.
#Install psycopg2 with pip: pip install psycopg2-binary
#Use the provided credentials to establish the connection.
import psycopg2

db_params = {
    "dbname": "postgres",
    "user": "testtech",
    "password":os.getenv("DB_PASSWORD"),#os.getenv()
    "host": "testtech.postgres.database.azure.com",
    "port": "5432"}
conn = None  # Initialize conn to None
cursor = None  # Initialize cursor to None




try:
    # Connect to PostgreSQL
    conn = psycopg2.connect(**db_params)
    cursor = conn.cursor()
    
    # SQL Insert Query
    insert_query = """
    INSERT INTO feven (link, title, time_uploaded, author, tags, reading_time, article_content, word_count, sentiment, compound_score)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    ON CONFLICT (link) DO NOTHING;  -- Avoids duplicate primary key errors
    """
    
    # Insert DataFrame records one by one
    for _, row in df.iterrows():
        cursor.execute(insert_query, (
            row['link'], row['title'], row['time_uploaded'], row['author'], row['tags'],
            row['reading_time'], row['article_content'], row['word_count'], row['sentiment'], row['compound_score']
        ))

    # Commit and close
    conn.commit()
    print("Data inserted successfully!")

except Exception as e:
    print("Error:", e)
finally:
    if cursor:
        cursor.close()  # Close the cursor if it's open
    if conn:
        conn.close()  # Close the connection if it's open
#"password": os.getenv("DB_PASSWORD")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       1 #Use the psycopg2 library to connect to the PostgreSQL database from your Python environment.
#       2 #Install psycopg2 with pip: pip install psycopg2-binary
#       3 #Use the provided credentials to establish the connection.
#       4 import psycopg2
#       6 db_params = {
#       7     "dbname": "postgres",
#       8     "user": "testtech",
# ----> 9     "password":os.getenv("DB_PASSWORD"),#os.getenv()
#      10     "host": "testtech.postgres.database.azure.com",
#      11     "port": "5432"}
#      12 conn = None  # Initialize conn to None
#      13 cursor = None  # Initialize cursor to None
#
# NameError: name 'os' is not defined
