# 24  Mental Health in the Digital Age: Why Gen Z Ne...  2025-03-22T02:40:35Z
#
#                     Author                                              Tags  \
# 0           Sahithya Priya
# 1             Rijul Rajesh                 #chatgpt#ai#programming#beginners
# 2         FUNDAMENTOS JAVA                                 #programming#java
# 3           johnsone emett
# 4   Learn Computer Academy
# 5           johnsone emett
# 6         FUNDAMENTOS JAVA                                 #programming#java
# 7                  Sathish                           #llm#ai#machinelearning
# 8         FUNDAMENTOS JAVA                                 #programming#java
# 9              Angie Jones                                   #mcp#ai#aiagent
# 10       Vladimir Grichina                #ai#webdev#productivity#opensource
# 11                   程序员一鸣                                            #鸿蒙分割线
# 12          Vanessa Martin  #webdev#javascript#softwareengineering#beginners
# 13                   程序员一鸣
# 14        FUNDAMENTOS JAVA                                 #programming#java
# 15                   程序员一鸣                                            #鸿蒙rcp
# 16                   程序员一鸣                                            #鸿蒙rcp
# 17           Michael James
# 18                   程序员一鸣                                            #arkts
# 19                   程序员一鸣                                            #arkts
# 20                   程序员一鸣                                            #arkts
# 21                   程序员一鸣                                            #arkts
# 22                   程序员一鸣                                            #arkts
# 23                   程序员一鸣                                             #鸿蒙权限
# 24          Pallavi Shukla
#
#    Reading Time                                    Article Content  \
# 0    1 min read  Periodic table of DevSecOps provides you with ...
# 1    3 min read  AI tools like ChatGPT have become indispensabl...
# 2    1 min read  Por que average() não retorna double diretamen...
# 3    4 min read
# 4    8 min read  In the modern web development landscape, creat...
# 5    2 min read
# 6    1 min read  Problema com Stream: Solução com IntStream: Di...
# 7    4 min read  If you’ve ever asked ChatGPT to describe an im...
# 8    1 min read  Problema na abordagem tradicional: Solução com...
# 9    2 min read  If you’re working with Model Context Protocol,...
# 10   4 min read  I'm Vlad, creator of poorcoder. This tool stre...
# 11   1 min read  本文基于Api13 分割线的场景非常之多，特别常见于列表中，随便打开一个应用，都能够找到分割...
# 12   1 min read
# 13   1 min read  本文基于Api13。 有两个组件，暂且不论横向纵向，后一个组件需要占满剩下的空间，该如何绘制...
# 14   3 min read  Podemos usar o método collect para resgatar es...
# 15   1 min read  本文基于Api13。 上篇文章，简单的对rcp中的会话问题做了概述，本篇文章，我们聊一聊rc...
# 16   1 min read  本文基于Api13。 之前开源过一个基于rcp，也就是基于Remote Communicat...
# 17   3 min read  Java is a powerful and versatile programming l...
# 18   2 min read  本篇文章节选于主要讲述ArkTs语言注释相关，所有案例均基于Api13。 所谓注释，在程序开...
# 19   1 min read  本文代码案例基于Api13。 正因为有了变量和常量，才有了程序之间的数据存储和管理，无论是变...
# 20   2 min read  本文代码案例基于Api13。 数据类型，在开发中是最常见的，无论是哪一种语言，无时无刻不在与...
# 21   1 min read  本文代码案例基于Api13。 字符串在实际的开发中还是非常重要的，牵扯到的用法也是比较多的，...
# 22   1 min read  本文基于Api13。 一句话解读：ArkTs（方舟编程语言）是目前HarmonyOs应用开发...
# 23   3 min read  本文基于Api13。 关于权限相关的知识点，陆陆续续分享了三篇了，也在前边的文章中关于权限的...
# 24   2 min read  Let’s be real—life can be A LOT. Between endle...
#
#     Word Count Sentiment  Compound Score
# 0           54  Positive          0.8591
# 1          518  Positive          0.9964
# 16                                 鸿蒙开发：远场通信服务rcp会话问题  2025-03-22T02:51:55Z
# 17  10 Essential Java Tips and Tricks Every Develo...  2025-03-22T02:50:21Z
# 18                                     鸿蒙开发：ArkTs语言注释  2025-03-22T02:50:03Z
# 19                                  鸿蒙开发：ArkTs语言变量和常量  2025-03-22T02:44:52Z
# 20                                     鸿蒙开发：ArkTs数据类型  2025-03-22T02:44:14Z
# 21                                鸿蒙开发：ArkTs字符串string  2025-03-22T02:43:39Z
# 22                                     鸿蒙开发：什么是ArkTs？  2025-03-22T02:43:05Z
# 23                                        鸿蒙开发：权限授权封装  2025-03-22T02:41:55Z
# 24  Mental Health in the Digital Age: Why Gen Z Ne...  2025-03-22T02:40:35Z
#
#                     Author                                              Tags  \
# 0           Sahithya Priya
# 1             Rijul Rajesh                 #chatgpt#ai#programming#beginners
# 2         FUNDAMENTOS JAVA                                 #programming#java
# 3           johnsone emett
# 4   Learn Computer Academy
# 5           johnsone emett
# 6         FUNDAMENTOS JAVA                                 #programming#java
# 7                  Sathish                           #llm#ai#machinelearning
# 8         FUNDAMENTOS JAVA                                 #programming#java
# 9              Angie Jones                                   #mcp#ai#aiagent
# 10       Vladimir Grichina                #ai#webdev#productivity#opensource
# 11                   程序员一鸣                                            #鸿蒙分割线
# 12          Vanessa Martin  #webdev#javascript#softwareengineering#beginners
# 13                   程序员一鸣
# 14        FUNDAMENTOS JAVA                                 #programming#java
# 15                   程序员一鸣                                            #鸿蒙rcp
# 16                   程序员一鸣                                            #鸿蒙rcp
# 17           Michael James
# 18                   程序员一鸣                                            #arkts
# 19                   程序员一鸣                                            #arkts
# 20                   程序员一鸣                                            #arkts
# 21                   程序员一鸣                                            #arkts
# 22                   程序员一鸣                                            #arkts
# 23                   程序员一鸣                                             #鸿蒙权限
# 24          Pallavi Shukla
#
#    Reading Time                                    Article Content  \
# 0    1 min read  Periodic table of DevSecOps provides you with ...
# 1    3 min read  AI tools like ChatGPT have become indispensabl...
# 2    1 min read  Por que average() não retorna double diretamen...
# 3    4 min read
# 4    8 min read  In the modern web development landscape, creat...
# 5    2 min read
# 6    1 min read  Problema com Stream: Solução com IntStream: Di...
# 7    4 min read  If you’ve ever asked ChatGPT to describe an im...
# 8    1 min read  Problema na abordagem tradicional: Solução com...
# 9    2 min read  If you’re working with Model Context Protocol,...
# 10   4 min read  I'm Vlad, creator of poorcoder. This tool stre...
# 11   1 min read  本文基于Api13 分割线的场景非常之多，特别常见于列表中，随便打开一个应用，都能够找到分割...
# 12   1 min read
# 13   1 min read  本文基于Api13。 有两个组件，暂且不论横向纵向，后一个组件需要占满剩下的空间，该如何绘制...
# 14   3 min read  Podemos usar o método collect para resgatar es...
# 15   1 min read  本文基于Api13。 上篇文章，简单的对rcp中的会话问题做了概述，本篇文章，我们聊一聊rc...
# 16   1 min read  本文基于Api13。 之前开源过一个基于rcp，也就是基于Remote Communicat...
# 17   3 min read  Java is a powerful and versatile programming l...
# 18   2 min read  本篇文章节选于主要讲述ArkTs语言注释相关，所有案例均基于Api13。 所谓注释，在程序开...
# 19   1 min read  本文代码案例基于Api13。 正因为有了变量和常量，才有了程序之间的数据存储和管理，无论是变...
# 20   2 min read  本文代码案例基于Api13。 数据类型，在开发中是最常见的，无论是哪一种语言，无时无刻不在与...
# 21   1 min read  本文代码案例基于Api13。 字符串在实际的开发中还是非常重要的，牵扯到的用法也是比较多的，...
# 22   1 min read  本文基于Api13。 一句话解读：ArkTs（方舟编程语言）是目前HarmonyOs应用开发...
# 23   3 min read  本文基于Api13。 关于权限相关的知识点，陆陆续续分享了三篇了，也在前边的文章中关于权限的...
# 24   2 min read  Let’s be real—life can be A LOT. Between endle...
#
#     Word Count Sentiment  Compound Score
# 0           54  Positive          0.8591
# 1          518  Positive          0.9964
# 2           52   Neutral          0.0000
# 3            0   Neutral          0.0000
# 4          331  Positive          0.9967
# 5            0   Neutral          0.0000
# 6           33   Neutral          0.0000
# 7          411  Positive          0.9927
# 8           20  Negative         -0.2960
# 9          107  Positive          0.9691
# 10         463  Positive          0.9775
# 11          20   Neutral          0.0000
# 12           0   Neutral          0.0000
# 13          28   Neutral          0.0000
# 14         345  Negative         -0.7393
# 15          18   Neutral          0.0000
# 16          23   Neutral          0.0000
# 17         458  Positive          0.9971
# 18          58   Neutral          0.0000
# 19          25   Neutral          0.0000
# 20         564  Positive          0.8460
# 21          65   Neutral          0.0000
# 22          46   Neutral          0.0000
# 23          10   Neutral          0.0000
# 24         382  Positive          0.9882

# %%
#Iterate through each column name.
#Convert the column name to lowercase.
#Replace any spaces in the column name with underscores (_).
#Example: "Time Uploaded" becomes "time_uploaded".
#Access the "reading_time" column.
#For each value in the column, remove the string " min read" from the end.
#Ensure that the remaining value in the column is converted to the appropriate datatype, probably an integer.
#Access the "article_content" column.
#For each value in the column, replace all occurrences of the newline character (\n) with an empty string ("").

df.columns=[x.lower() for x in df.columns] # this methodis called list comprehension
df.columns=[x.replace(' ','_') for x in df.columns] 
df['reading_time']=df['reading_time'].str.replace(' min read','')
df['article_content']=df['article_content'].str.replace('\n','')

df
# Out:
#                                                  link  \
# 0   https://dev.to/iamsahithya/periodic-table-of-d...
# 1   https://dev.to/rijultp/precision-prompting-how...
# 2   https://dev.to/fundamentosjava/78-o-optional-e...
# 3   https://dev.to/johnsone_emett_c5c2b56a4a/stack...
# 4   https://dev.to/learncomputer/developing-a-resp...
# 5   https://dev.to/johnsone_emett_c5c2b56a4a/searc...
# 6   https://dev.to/fundamentosjava/77-intstream-e-...
# 7   https://dev.to/sathish/how-llms-understand-ima...
# 8   https://dev.to/fundamentosjava/76-liste-apenas...
# 9   https://dev.to/techgirl1908/my-favorite-mcp-di...
# 10  https://dev.to/vgrichina/vibe-coding-a-web-pon...
# 11  https://dev.to/abnerming888/hong-meng-kai-fa-l...
# 12  https://dev.to/vsm1996/great-easy-to-follow-co...
# 13  https://dev.to/abnerming888/hong-meng-kai-fa-t...
# 14  https://dev.to/fundamentosjava/74-collectors-361a
# 15  https://dev.to/abnerming888/hong-meng-kai-fa-y...
# 16  https://dev.to/abnerming888/hong-meng-kai-fa-y...
# 17  https://dev.to/michael_james123/10-essential-j...
# 18  https://dev.to/abnerming888/hong-meng-kai-fa-a...
# 19  https://dev.to/abnerming888/hong-meng-kai-fa-a...
# 20  https://dev.to/abnerming888/hong-meng-kai-fa-a...
# 21  https://dev.to/abnerming888/hong-meng-kai-fa-a...
#
# 2             1  Por que average() não retorna double diretamen...
# 3             4
# 4             8  In the modern web development landscape, creat...
# 5             2
# 6             1  Problema com Stream: Solução com IntStream: Di...
# 7             4  If you’ve ever asked ChatGPT to describe an im...
# 8             1  Problema na abordagem tradicional: Solução com...
# 9             2  If you’re working with Model Context Protocol,...
# 10            4  I'm Vlad, creator of poorcoder. This tool stre...
# 11            1  本文基于Api13 分割线的场景非常之多，特别常见于列表中，随便打开一个应用，都能够找到分割...
# 12            1
# 13            1  本文基于Api13。 有两个组件，暂且不论横向纵向，后一个组件需要占满剩下的空间，该如何绘制...
# 14            3  Podemos usar o método collect para resgatar es...
# 15            1  本文基于Api13。 上篇文章，简单的对rcp中的会话问题做了概述，本篇文章，我们聊一聊rc...
# 16            1  本文基于Api13。 之前开源过一个基于rcp，也就是基于Remote Communicat...
# 17            3  Java is a powerful and versatile programming l...
# 18            2  本篇文章节选于主要讲述ArkTs语言注释相关，所有案例均基于Api13。 所谓注释，在程序开...
# 19            1  本文代码案例基于Api13。 正因为有了变量和常量，才有了程序之间的数据存储和管理，无论是变...
# 20            2  本文代码案例基于Api13。 数据类型，在开发中是最常见的，无论是哪一种语言，无时无刻不在与...
# 21            1  本文代码案例基于Api13。 字符串在实际的开发中还是非常重要的，牵扯到的用法也是比较多的，...
# 22            1  本文基于Api13。 一句话解读：ArkTs（方舟编程语言）是目前HarmonyOs应用开发...
# 23            3  本文基于Api13。 关于权限相关的知识点，陆陆续续分享了三篇了，也在前边的文章中关于权限的...
# 24            2  Let’s be real—life can be A LOT. Between endle...
#
#     word_count sentiment  compound_score
# 0           54  Positive          0.8591
# 1          518  Positive          0.9964
# 2           52   Neutral          0.0000
# 3            0   Neutral          0.0000
# 4          331  Positive          0.9967
# 5            0   Neutral          0.0000
# 6           33   Neutral          0.0000
# 7          411  Positive          0.9927
# 8           20  Negative         -0.2960
# 9          107  Positive          0.9691
# 10         463  Positive          0.9775
# 11          20   Neutral          0.0000
# 12           0   Neutral          0.0000
# 13          28   Neutral          0.0000
# 14         345  Negative         -0.7393
# 15          18   Neutral          0.0000
# 16          23   Neutral          0.0000
# 17         458  Positive          0.9971
# 18          58   Neutral          0.0000
# 19          25   Neutral          0.0000
# 20         564  Positive          0.8460
# 21          65   Neutral          0.0000
# 22          46   Neutral          0.0000
# 23          10   Neutral          0.0000
# 24         382  Positive          0.9882

# %%
#After the transformations, ensure that each column has the correct data type (e.g., integer, string, date, etc.).
 #You might need to use Pandas functions like astype() to enforce these data types.
#Determine the appropriate data types for each column based on the data that it contains.

import pandas as pd
df = df.astype({
    'link': 'string',
    'title': 'string',
    'time_uploaded': 'string',  # Can be converted to datetime later
    'author': 'string',
    'tags': 'string',
    'reading_time': 'int64',
    'article_content': 'string',
    'word_count': 'int64',
    'sentiment': 'string',
    'compound_score': 'float64'
})


df['time_uploaded'] = pd.to_datetime(df['time_uploaded'])
df
# Out:
#                                                  link  \
# 0   https://dev.to/iamsahithya/periodic-table-of-d...
# 1   https://dev.to/rijultp/precision-prompting-how...
# 2   https://dev.to/fundamentosjava/78-o-optional-e...
# 15 2025-03-22 02:53:22+00:00                   程序员一鸣
# 16 2025-03-22 02:51:55+00:00                   程序员一鸣
# 17 2025-03-22 02:50:21+00:00           Michael James
# 18 2025-03-22 02:50:03+00:00                   程序员一鸣
# 19 2025-03-22 02:44:52+00:00                   程序员一鸣
# 20 2025-03-22 02:44:14+00:00                   程序员一鸣
# 21 2025-03-22 02:43:39+00:00                   程序员一鸣
# 22 2025-03-22 02:43:05+00:00                   程序员一鸣
# 23 2025-03-22 02:41:55+00:00                   程序员一鸣
# 24 2025-03-22 02:40:35+00:00          Pallavi Shukla
#
#                                                 tags  reading_time  \
# 0                                                                1
# 1                  #chatgpt#ai#programming#beginners             3
# 2                                  #programming#java             1
# 3                                                                4
# 4                                                                8
# 5                                                                2
# 6                                  #programming#java             1
# 7                            #llm#ai#machinelearning             4
# 8                                  #programming#java             1
# 9                                    #mcp#ai#aiagent             2
# 10                #ai#webdev#productivity#opensource             4
# 11                                            #鸿蒙分割线             1
# 12  #webdev#javascript#softwareengineering#beginners             1
# 13                                                               1
# 14                                 #programming#java             3
# 15                                            #鸿蒙rcp             1
# 16                                            #鸿蒙rcp             1
# 17                                                               3
# 18                                            #arkts             2
# 19                                            #arkts             1
# 20                                            #arkts             2
# 21                                            #arkts             1
# 22                                            #arkts             1
# 23                                             #鸿蒙权限             3
# 24                                                               2
#
#                                       article_content  word_count sentiment  \
# 0   Periodic table of DevSecOps provides you with ...          54  Positive
# 1   AI tools like ChatGPT have become indispensabl...         518  Positive
# 2   Por que average() não retorna double diretamen...          52   Neutral
# 3                                                               0   Neutral
# 4   In the modern web development landscape, creat...         331  Positive
# 5                                                               0   Neutral
# 6   Problema com Stream: Solução com IntStream: Di...          33   Neutral
# 7   If you’ve ever asked ChatGPT to describe an im...         411  Positive
# 8   Problema na abordagem tradicional: Solução com...          20  Negative
# 9   If you’re working with Model Context Protocol,...         107  Positive
# 10  I'm Vlad, creator of poorcoder. This tool stre...         463  Positive
# 11  本文基于Api13 分割线的场景非常之多，特别常见于列表中，随便打开一个应用，都能够找到分割...          20   Neutral
# 12                                                              0   Neutral
# 13  本文基于Api13。 有两个组件，暂且不论横向纵向，后一个组件需要占满剩下的空间，该如何绘制...          28   Neutral
# 14  Podemos usar o método collect para resgatar es...         345  Negative
# 15  本文基于Api13。 上篇文章，简单的对rcp中的会话问题做了概述，本篇文章，我们聊一聊rc...          18   Neutral
# 16  本文基于Api13。 之前开源过一个基于rcp，也就是基于Remote Communicat...          23   Neutral
# 17  Java is a powerful and versatile programming l...         458  Positive
# 18  本篇文章节选于主要讲述ArkTs语言注释相关，所有案例均基于Api13。 所谓注释，在程序开...          58   Neutral
# 19  本文代码案例基于Api13。 正因为有了变量和常量，才有了程序之间的数据存储和管理，无论是变...          25   Neutral
# 20  本文代码案例基于Api13。 数据类型，在开发中是最常见的，无论是哪一种语言，无时无刻不在与...         564  Positive
# 21  本文代码案例基于Api13。 字符串在实际的开发中还是非常重要的，牵扯到的用法也是比较多的，...          65   Neutral
# 22  本文基于Api13。 一句话解读：ArkTs（方舟编程语言）是目前HarmonyOs应用开发...          46   Neutral
# 23  本文基于Api13。 关于权限相关的知识点，陆陆续续分享了三篇了，也在前边的文章中关于权限的...          10   Neutral
# 24  Let’s be real—life can be A LOT. Between endle...         382  Positive
#
#     compound_score
# 0           0.8591
# 1           0.9964
# 2           0.0000
# 3           0.0000
# 4           0.9967
# 5           0.0000
# 6           0.0000
# 7           0.9927
# 8          -0.2960
# 9           0.9691
# 10          0.9775
# 11          0.0000
# 12          0.0000
# 13          0.0000
# 14         -0.7393
# 15          0.0000
# 16          0.0000
# 17          0.9971
# 18          0.0000
# 19          0.0000
# 20          0.8460
# 21          0.0000
# 22          0.0000
# 23          0.0000
# 24          0.9882

# %%
df
# Out:
#                                                  link  \
# 0   https://dev.to/iamsahithya/periodic-table-of-d...
# 1   https://dev.to/rijultp/precision-prompting-how...
# 2   https://dev.to/fundamentosjava/78-o-optional-e...
# 3   https://dev.to/johnsone_emett_c5c2b56a4a/stack...
# 4   https://dev.to/learncomputer/developing-a-resp...
# 5   https://dev.to/johnsone_emett_c5c2b56a4a/searc...
# 6   https://dev.to/fundamentosjava/77-intstream-e-...
# 7   https://dev.to/sathish/how-llms-understand-ima...
# 8   https://dev.to/fundamentosjava/76-liste-apenas...
# 9   https://dev.to/techgirl1908/my-favorite-mcp-di...
# 10  https://dev.to/vgrichina/vibe-coding-a-web-pon...
# 11  https://dev.to/abnerming888/hong-meng-kai-fa-l...
# 12  https://dev.to/vsm1996/great-easy-to-follow-co...
# 13  https://dev.to/abnerming888/hong-meng-kai-fa-t...
# 14  https://dev.to/fundamentosjava/74-collectors-361a
# 15  https://dev.to/abnerming888/hong-meng-kai-fa-y...
# 16  https://dev.to/abnerming888/hong-meng-kai-fa-y...
# 17  https://dev.to/michael_james123/10-essential-j...
# 18  https://dev.to/abnerming888/hong-meng-kai-fa-a...
# 19  https://dev.to/abnerming888/hong-meng-kai-fa-a...
# 20  https://dev.to/abnerming888/hong-meng-kai-fa-a...
# 21  https://dev.to/abnerming888/hong-meng-kai-fa-a...
# 22  https://dev.to/abnerming888/hong-meng-kai-fa-s...
# 23  https://dev.to/abnerming888/hong-meng-kai-fa-q...
# 24  https://dev.to/pallavi_shukla_28ce5b0a4e/menta...
#
#                                                 title  \
# 0                         Periodic table of DevSecOps
# 1   Precision Prompting: How to Get AI to Say Exac...
# 2                         7.8 O Optional em java.util
# 3                                              stacks
# 4   Developing a Responsive Web Tester: Build Your...
# 5                                   search/sort algos
# 6                7.7 IntStream e a família de Streams
# 7   How LLMs Understand Images: The Secret Behind ...
# 8   7.6 Liste apenas os pontos de todos os usuário...
# 9                         My Favorite MCP Directories
# 10  Vibe Coding a Web Pong Game with poorcoder and...
# 11                                         鸿蒙开发：了解分割线
# 12                     Great, easy-to-follow content!
# 13                                        鸿蒙开发：填充剩余空间
# 14                               7.4 e 7.5 Collectors
# 15                                鸿蒙开发，远场通信服务rcp拦截器问题
# 16                                 鸿蒙开发：远场通信服务rcp会话问题
# 17  10 Essential Java Tips and Tricks Every Develo...
# 18                                     鸿蒙开发：ArkTs语言注释
# 19                                  鸿蒙开发：ArkTs语言变量和常量
# 20                                     鸿蒙开发：ArkTs数据类型
# 21                                鸿蒙开发：ArkTs字符串string
# 22                                     鸿蒙开发：什么是ArkTs？
# 23                                        鸿蒙开发：权限授权封装
# 24  Mental Health in the Digital Age: Why Gen Z Ne...
#
#                time_uploaded                  author  \
# 0  2025-03-22 03:38:44+00:00          Sahithya Priya
# 1  2025-03-22 03:37:50+00:00            Rijul Rajesh
# 2  2025-03-22 03:33:12+00:00        FUNDAMENTOS JAVA
# 3  2025-03-22 03:30:55+00:00          johnsone emett
# 4  2025-03-22 03:30:00+00:00  Learn Computer Academy
# 5  2025-03-22 03:29:13+00:00          johnsone emett
# 6  2025-03-22 03:23:06+00:00        FUNDAMENTOS JAVA
# 7  2025-03-22 03:18:00+00:00                 Sathish
# 8  2025-03-22 03:17:30+00:00        FUNDAMENTOS JAVA
# 9  2025-03-22 03:03:04+00:00             Angie Jones
# 10 2025-03-22 02:57:05+00:00       Vladimir Grichina
# 11 2025-03-22 02:57:03+00:00                   程序员一鸣
# 12 2025-03-22 02:56:21+00:00          Vanessa Martin
# 13 2025-03-22 02:55:08+00:00                   程序员一鸣
# 14 2025-03-22 02:54:53+00:00        FUNDAMENTOS JAVA
# 15 2025-03-22 02:53:22+00:00                   程序员一鸣
# 16 2025-03-22 02:51:55+00:00                   程序员一鸣
# 17 2025-03-22 02:50:21+00:00           Michael James
# 18 2025-03-22 02:50:03+00:00                   程序员一鸣
# 19 2025-03-22 02:44:52+00:00                   程序员一鸣
# 20 2025-03-22 02:44:14+00:00                   程序员一鸣
# 21 2025-03-22 02:43:39+00:00                   程序员一鸣
# 22 2025-03-22 02:43:05+00:00                   程序员一鸣
# 23 2025-03-22 02:41:55+00:00                   程序员一鸣
# 24 2025-03-22 02:40:35+00:00          Pallavi Shukla
#
#                                                 tags  reading_time  \
# 0                                                                1
# 1                  #chatgpt#ai#programming#beginners             3
# 2                                  #programming#java             1
# 3                                                                4
# 4                                                                8
# 5                                                                2
# 6                                  #programming#java             1
# 7                            #llm#ai#machinelearning             4
# 8                                  #programming#java             1
# 9                                    #mcp#ai#aiagent             2
# 10                #ai#webdev#productivity#opensource             4
# 11                                            #鸿蒙分割线             1
# 12  #webdev#javascript#softwareengineering#beginners             1
# 13                                                               1
# 14                                 #programming#java             3
# 15                                            #鸿蒙rcp             1
# 16                                            #鸿蒙rcp             1
# 17                                                               3
# 18                                            #arkts             2
# 19                                            #arkts             1
# 20                                            #arkts             2
# 21                                            #arkts             1
# 22                                            #arkts             1
# 23                                             #鸿蒙权限             3
# 24                                                               2
#
#                                       article_content  word_count sentiment  \
# 0   Periodic table of DevSecOps provides you with ...          54  Positive
# 1   AI tools like ChatGPT have become indispensabl...         518  Positive
# 2   Por que average() não retorna double diretamen...          52   Neutral
# 3                                                               0   Neutral
# 4   In the modern web development landscape, creat...         331  Positive
# 5                                                               0   Neutral
# 6   Problema com Stream: Solução com IntStream: Di...          33   Neutral
# 7   If you’ve ever asked ChatGPT to describe an im...         411  Positive
# 8   Problema na abordagem tradicional: Solução com...          20  Negative
# 9   If you’re working with Model Context Protocol,...         107  Positive
# 10  I'm Vlad, creator of poorcoder. This tool stre...         463  Positive
# 11  本文基于Api13 分割线的场景非常之多，特别常见于列表中，随便打开一个应用，都能够找到分割...          20   Neutral
# 12                                                              0   Neutral
# 13  本文基于Api13。 有两个组件，暂且不论横向纵向，后一个组件需要占满剩下的空间，该如何绘制...          28   Neutral
# 14  Podemos usar o método collect para resgatar es...         345  Negative
# 15  本文基于Api13。 上篇文章，简单的对rcp中的会话问题做了概述，本篇文章，我们聊一聊rc...          18   Neutral
# 16  本文基于Api13。 之前开源过一个基于rcp，也就是基于Remote Communicat...          23   Neutral
# 17  Java is a powerful and versatile programming l...         458  Positive
# 18  本篇文章节选于主要讲述ArkTs语言注释相关，所有案例均基于Api13。 所谓注释，在程序开...          58   Neutral
# 19  本文代码案例基于Api13。 正因为有了变量和常量，才有了程序之间的数据存储和管理，无论是变...          25   Neutral
# 20  本文代码案例基于Api13。 数据类型，在开发中是最常见的，无论是哪一种语言，无时无刻不在与...         564  Positive
# 21  本文代码案例基于Api13。 字符串在实际的开发中还是非常重要的，牵扯到的用法也是比较多的，...          65   Neutral
# 22  本文基于Api13。 一句话解读：ArkTs（方舟编程语言）是目前HarmonyOs应用开发...          46   Neutral
# 23  本文基于Api13。 关于权限相关的知识点，陆陆续续分享了三篇了，也在前边的文章中关于权限的...          10   Neutral
# 24  Let’s be real—life can be A LOT. Between endle...         382  Positive
#
#     compound_score
# 0           0.8591
# 1           0.9964
# 2           0.0000
# 3           0.0000
# 4           0.9967
# 5           0.0000
# 6           0.0000
# 7           0.9927
# 8          -0.2960
# 9           0.9691
# 10          0.9775
# 11          0.0000
# 12          0.0000
# 13          0.0000
# 14         -0.7393
# 15          0.0000
# 16          0.0000
# 17          0.9971
# 18          0.0000
# 19          0.0000
# 20          0.8460
# 21          0.0000
# 22          0.0000
# 23          0.0000
# 24          0.9882

# %%
#Open pgAdmin.
#Create a new server connection using the provided credentials:
#In the connected database, create a new table with your name (e.g., yourname).
#Define the columns with appropriate data types:

#The link column must be defined as the primary key.
#Analyze the transformed data to determine the correct data type for each column.
#Examples of datatypes are: text, integer, timestamp, date.
# Database connection parameters
db_params = {
    "dbname": "postgres",
    "user": "testtech",
    "password":  os.getenv("DB_PASSWORD"),#os.getenv()
    "host": "testtech.postgres.database.azure.com",
    "port": "5432"
}

# %%
#Use the psycopg2 library to connect to the PostgreSQL database from your Python environment.
#Install psycopg2 with pip: pip install psycopg2-binary
#Use the provided credentials to establish the connection.
try:
    # Connect to PostgreSQL
    conn = psycopg2.connect(**db_params)
    cursor = conn.cursor()
    
    # SQL Insert Query
    insert_query = """
    INSERT INTO feven (link, title, time_uploaded, author, tags, reading_time, article_content, word_count, sentiment, compound_score)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    ON CONFLICT (link) DO NOTHING;  -- Avoids duplicate primary key errors
    """
    
    # Insert DataFrame records one by one
    for _, row in df.iterrows():
        cursor.execute(insert_query, (
            row['link'], row['title'], row['time_uploaded'], row['author'], row['tags'],
            row['reading_time'], row['article_content'], row['word_count'], row['sentiment'], row['compound_score']
        ))

    # Commit and close
    conn.commit()
    print("Data inserted successfully!")

except Exception as e:
    print("Error:", e)

finally:
    if conn:
        cursor.close()
        conn.close()
#"password": os.getenv("DB_PASSWORD")
# Out:
# Error: name 'psycopg2' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 31
#      28     print("Error:", e)
#      30 finally:
# ---> 31     if conn:
#      32         cursor.close()
#      33         conn.close()
#
# NameError: name 'conn' is not defined
