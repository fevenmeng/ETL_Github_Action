# %%
# Define your Azure PostgreSQL connection details
    USERNAME = "testtech"
    PASSWORD = "Your_password"
    HOST = "testtech.postgres.database.azure.com"
    PORT = "5432"  # Default PostgreSQL port
    DATABASE = "postgres"

    # Create the database connection URL
    DATABASE_URL = f"postgresql://{USERNAME}:{PASSWORD}@{HOST}:{PORT}/{DATABASE}"

    # Create an SQLAlchemy engine
    engine = create_engine(DATABASE_URL)



    # Push DataFrame to Azure PostgreSQL
    df.to_sql("player_table", engine, if_exists="append", index=False)

    print("Data pushed successfully!")
# Out:
#   Cell In[4], line 2
#     USERNAME = "testtech"
#     ^
# IndentationError: unexpected indent

# %%
from get_data import get_article_data

df = get_article_data()
df
# Out:
# [nltk_data] Downloading package stopwords to /home/gitpod/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/gitpod/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/gitpod/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/gitpod/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/gitpod/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
#                                                  Link  \
# 0   https://dev.to/anna_golubkova/what-are-the-adv...
# 1   https://dev.to/aein_bagheri_10ffa69696b9/bdh-2...
# 2   https://dev.to/aein_bagheri_10ffa69696b9/anyth...
# 3   https://dev.to/abiodun_omotunde/fundamental-co...
# 4          https://dev.to/arunkrish11/vim-is-gem-3kh7
# 5   https://dev.to/the_greatbonnie/if-you-are-look...
# 6   https://dev.to/phsaurav/breaking-free-from-ai-...
# 7   https://dev.to/broflovski/my-journey-into-elix...
# 8   https://dev.to/cristianalex_17/how-does-hibern...
# 9              https://dev.to/arun04hack/why-none-dh4
# 10  https://dev.to/jenelyn/hello-everyone-im-jen-a...
# 11  https://dev.to/niko_doing_dev/frontiend-dlia-w...
# 12  https://dev.to/es-devej/que-tecnologias-usar-e...
# 13  https://dev.to/haquedot/role-based-authenticat...
# 14  https://dev.to/henriqueotogami/como-piscar-um-...
# 15  https://dev.to/ktfth/hey-dev-announcement-abou...
# 16  https://dev.to/sabghat90/github-foundation-cer...
# 17  https://dev.to/saifuddin_saifee_f3ad0520/galax...
# 18  https://dev.to/raji_moshood_ee3a4c2638f6/why-n...
# 19  https://dev.to/jessicase0/how-samir-salih-is-t...
# 20   https://dev.to/mehmetakar/what-is-llm-in-ai-487d
# 21  https://dev.to/princemalikk/week-2-done-my-dev...
# 22  https://dev.to/imsushant12/cron-jobs-in-linux-...
# 23  https://dev.to/rijultp/how-behavioral-economic...
# 24  https://dev.to/sandeep_a67a84444cb5f3f6f/maste...
#
#                                                 Title         Time Uploaded  \
# 0   What Are the Advantages Of Hibernate Over Othe...  2025-03-15T20:27:13Z
# 1                                              بده ۲@  2025-03-15T20:44:42Z
# 2                                   Anything you! Add  2025-03-15T20:36:59Z
# 3             Fundamental Concepts In Cloud Computing  2025-03-15T20:18:51Z
# 4                                        VIM is gem!!  2025-03-15T20:04:35Z
# 5   If you are looking to fine-tune an AI model, c...  2025-03-15T20:03:43Z
# 6   Breaking Free from AI Subscriptions: Cost-Effe...  2025-03-15T19:57:25Z
# 7            My Journey into Elixir/Erlang (Part One)  2025-03-15T19:53:15Z
# 8   How Does Hibernate Support Inheritance Mapping...  2025-03-15T19:52:03Z
# 9                                           Why None?  2025-03-15T19:41:37Z
# 10  Hello everyone! 👋 I’m Jen, a Software Engineer...  2025-03-15T19:40:55Z
# 11           Фронтенд для Web3 dApp: хорошие практики  2025-03-15T19:33:33Z
# 12             Qué tecnologías usar en mi aplicación?  2025-03-15T19:31:05Z
# 13  Role-Based Authentication in Node.js with Expr...  2025-03-15T19:14:34Z
# 14  Como piscar um LED utilizando BananaPi e Pytho...  2025-03-15T19:07:54Z
# 15  Hey Dev! Announcement about a little project w...  2025-03-15T19:01:56Z
# 16     GitHub Foundation Certification Exam Questions  2025-03-15T19:01:52Z
# 17  Galaxy Book Pro's Internal Speaker Audio Issue...  2025-03-15T18:55:51Z
# 18  Why Nigerian Businesses Should Start Using Blo...  2025-03-15T18:51:56Z
# 19  How Samir Salih is Transforming the Mental Hea...  2025-03-15T18:49:42Z
# 20                                  What is LLM in AI  2025-03-15T18:47:54Z
# 21        Week 2 Done! 🚀 My DevOps Learning Journey 🎯  2025-03-15T18:34:11Z
# 22  Cron Jobs in Linux: Evolution from AT to Cron ...  2025-03-15T18:30:00Z
# 23  How Behavioral Economics Can Make Your UX Unfo...  2025-03-15T18:29:45Z
# 24      "Mastering Pointers in C: A Beginner's Guide"  2025-03-15T18:27:57Z
#
#                             Author  \
# 0                   Anna Golubkova
# 1                             Aein
# 2                             Aein
# 3                 Abiodun Omotunde
# 4                       Arun Krish
# 5                           Bonnie
# 6                        PH Saurav
# 7                    azabroflovski
# 8                        Negrito 👌
# 9                             Arun
# 10                      Jen Ababan
# 11                    Niko Borisov
# 12                Enmanuel Jarquín
# 13                          Haque.
# 14  Henrique Matheus Alves Pereira
# 15                           ktfth
# 16                   Sabghat Ullah
# 17                Saifuddin Saifee
# 18                    Raji moshood
# 19                         Jessica
# 20                     mehmet akar
# 21                    Prince Malik
# 22                  Sushant Gaurav
# 23                    Rijul Rajesh
# 24                         Sandeep
#
#                                               Tags Reading Time  \
# 0                                                    2 min read
# 1   #kendoreactchallenge#react#devchallenge#webdev   1 min read
# 2          #devchallenge#githubchallenge#ai#webdev   1 min read
# 3                    #devops#azure#cloud#beginners   3 min read
# 4                     #beginners#tutorial#vim#code   3 min read
# 5                          #ai#deepseek#rag#python   1 min read
# 6   #ai#openrouter#programming#softwaredevelopment   6 min read
# 7                              #elixir#beam#erlang   5 min read
# 8                                                    3 min read
# 9         #discuss#python#sortfunction#programming   1 min read
# 10         #softwareengineering#networking#welcome   1 min read
# 11                                                   3 min read
# 12                    #webdev#javascript#beginners   4 min read
# 13                       #webdev#node#java#mongodb   3 min read
# 14                #raspberrypi#python#ssh#bananapi   4 min read
# 15                                 #showdev#github   1 min read
# 16    #github#githubfoundation#githubcertification  12 min read
# 17                  #linux#fedora#hardware#samsung   5 min read
# 18   #blockchain#cryptocurrency#web3#smartcontract   4 min read
# 19        #samir#salih#samirsalih#digitalmarketing   4 min read
# 20                       #ai#llm#llminai#whatisllm   2 min read
# 21                          #aws#devops#automation   2 min read
# 22         #linux#programming#beginners#opensource   2 min read
# 23                  #ux#psychology#webdev#learning   4 min read
# 24               #c#programming#pointers#beginners   2 min read
#
#                                       Article Content  Word Count Sentiment  \
# 0   Hibernate is one of the most popular Object-Re...         306  Positive
# 1                                                               0   Neutral
# 2                                                               0   Neutral
# 3   Cloud computing simply means delivery of compu...         400  Positive
# 4   What is VIM? Basically, VIM will help you to c...         152  Positive
# 5                                                               0   Neutral
# 6   AI is here to stay. From my early days with th...         784  Positive
# 7    Recently, I started diving into the world of ...         758  Positive
# 8   In the realm of Java-based applications, Hiber...         268  Positive
# 9   names = ["Eren", "luffy", "goku"]\nprint(names...          31   Neutral
# 10                                                              0   Neutral
# 11  Использование discriminated unions в TypeScrip...         295  Positive
# 12  Una de las cosas mas complicadas al inicio de ...         220  Negative
# 13  Introduction Role-Based Authentication (RBA) i...         196  Positive
# 14  Este artigo irá demonstrar como fazer um LED p...         442  Negative
# 15                                                              0   Neutral
# 16  What folder is the definition files stored in ...         667  Positive
# 17  This guide walks you through every step—from i...         467  Positive
# 18  Blockchain technology is no longer just for cr...         740  Positive
# 19   The mental health industry has witnessed a si...         414  Positive
# 20  What is LLM in AI? This is the most asked ques...         238  Positive
# 21  This week, I deep-dived into Shell Scripting f...         179  Negative
# 22  Task scheduling is a fundamental aspect of Lin...         180  Positive
# 23   It was a quiet evening, and Alex was scrollin...         381  Positive
# 24  If you're diving into C programming, you've pr...         223  Positive
#
#     Compound Score
# 0           0.9970
# 1           0.0000
# 2           0.0000
# 3           0.9630
# 4           0.9825
# 5           0.0000
# 6           0.9992
# 7           0.9985
# 8           0.9908
# 9           0.0000
# 10          0.0000
# 11          0.8316
# 12         -0.6808
# 13          0.9633
# 14         -0.3595
# 15          0.0000
# 16          0.9981
# 17          0.9883
# 18          0.9962
# 19          0.9978
# 20          0.9925
# 21         -0.4003
# 22          0.4574
# 23          0.9972
# 24          0.9831

# %%
df
# Out:
#                                                  Link  \
# 0   https://dev.to/anna_golubkova/what-are-the-adv...
# 1   https://dev.to/aein_bagheri_10ffa69696b9/bdh-2...
# 2   https://dev.to/aein_bagheri_10ffa69696b9/anyth...
# 3   https://dev.to/abiodun_omotunde/fundamental-co...
# 4          https://dev.to/arunkrish11/vim-is-gem-3kh7
# 5   https://dev.to/the_greatbonnie/if-you-are-look...
# 6   https://dev.to/phsaurav/breaking-free-from-ai-...
# 7   https://dev.to/broflovski/my-journey-into-elix...
# 8   https://dev.to/cristianalex_17/how-does-hibern...
# 9              https://dev.to/arun04hack/why-none-dh4
# 10  https://dev.to/jenelyn/hello-everyone-im-jen-a...
# 11  https://dev.to/niko_doing_dev/frontiend-dlia-w...
# 12  https://dev.to/es-devej/que-tecnologias-usar-e...
# 13  https://dev.to/haquedot/role-based-authenticat...
# 14  https://dev.to/henriqueotogami/como-piscar-um-...
# 15  https://dev.to/ktfth/hey-dev-announcement-abou...
# 16  https://dev.to/sabghat90/github-foundation-cer...
# 17  https://dev.to/saifuddin_saifee_f3ad0520/galax...
# 18  https://dev.to/raji_moshood_ee3a4c2638f6/why-n...
# 19  https://dev.to/jessicase0/how-samir-salih-is-t...
# 20   https://dev.to/mehmetakar/what-is-llm-in-ai-487d
# 21  https://dev.to/princemalikk/week-2-done-my-dev...
# 22  https://dev.to/imsushant12/cron-jobs-in-linux-...
# 23  https://dev.to/rijultp/how-behavioral-economic...
# 24  https://dev.to/sandeep_a67a84444cb5f3f6f/maste...
#
#                                                 Title         Time Uploaded  \
# 0   What Are the Advantages Of Hibernate Over Othe...  2025-03-15T20:27:13Z
# 1                                              بده ۲@  2025-03-15T20:44:42Z
# 2                                   Anything you! Add  2025-03-15T20:36:59Z
# 3             Fundamental Concepts In Cloud Computing  2025-03-15T20:18:51Z
# 4                                        VIM is gem!!  2025-03-15T20:04:35Z
# 5   If you are looking to fine-tune an AI model, c...  2025-03-15T20:03:43Z
# 6   Breaking Free from AI Subscriptions: Cost-Effe...  2025-03-15T19:57:25Z
# 7            My Journey into Elixir/Erlang (Part One)  2025-03-15T19:53:15Z
# 8   How Does Hibernate Support Inheritance Mapping...  2025-03-15T19:52:03Z
# 9                                           Why None?  2025-03-15T19:41:37Z
# 10  Hello everyone! 👋 I’m Jen, a Software Engineer...  2025-03-15T19:40:55Z
# 11           Фронтенд для Web3 dApp: хорошие практики  2025-03-15T19:33:33Z
# 12             Qué tecnologías usar en mi aplicación?  2025-03-15T19:31:05Z
# 13  Role-Based Authentication in Node.js with Expr...  2025-03-15T19:14:34Z
# 14  Como piscar um LED utilizando BananaPi e Pytho...  2025-03-15T19:07:54Z
# 15  Hey Dev! Announcement about a little project w...  2025-03-15T19:01:56Z
# 16     GitHub Foundation Certification Exam Questions  2025-03-15T19:01:52Z
# 17  Galaxy Book Pro's Internal Speaker Audio Issue...  2025-03-15T18:55:51Z
# 18  Why Nigerian Businesses Should Start Using Blo...  2025-03-15T18:51:56Z
# 19  How Samir Salih is Transforming the Mental Hea...  2025-03-15T18:49:42Z
# 20                                  What is LLM in AI  2025-03-15T18:47:54Z
# 21        Week 2 Done! 🚀 My DevOps Learning Journey 🎯  2025-03-15T18:34:11Z
# 22  Cron Jobs in Linux: Evolution from AT to Cron ...  2025-03-15T18:30:00Z
# 23  How Behavioral Economics Can Make Your UX Unfo...  2025-03-15T18:29:45Z
# 24      "Mastering Pointers in C: A Beginner's Guide"  2025-03-15T18:27:57Z
#
#                             Author  \
# 0                   Anna Golubkova
# 1                             Aein
# 2                             Aein
# 3                 Abiodun Omotunde
# 4                       Arun Krish
# 5                           Bonnie
# 6                        PH Saurav
# 7                    azabroflovski
# 8                        Negrito 👌
# 9                             Arun
# 10                      Jen Ababan
# 11                    Niko Borisov
# 12                Enmanuel Jarquín
# 13                          Haque.
# 14  Henrique Matheus Alves Pereira
# 15                           ktfth
# 16                   Sabghat Ullah
# 17                Saifuddin Saifee
# 18                    Raji moshood
# 19                         Jessica
# 20                     mehmet akar
# 21                    Prince Malik
# 22                  Sushant Gaurav
# 23                    Rijul Rajesh
# 24                         Sandeep
#
#                                               Tags Reading Time  \
# 0                                                    2 min read
# 1   #kendoreactchallenge#react#devchallenge#webdev   1 min read
# 2          #devchallenge#githubchallenge#ai#webdev   1 min read
# 3                    #devops#azure#cloud#beginners   3 min read
# 4                     #beginners#tutorial#vim#code   3 min read
# 5                          #ai#deepseek#rag#python   1 min read
# 6   #ai#openrouter#programming#softwaredevelopment   6 min read
# 7                              #elixir#beam#erlang   5 min read
# 8                                                    3 min read
# 9         #discuss#python#sortfunction#programming   1 min read
# 10         #softwareengineering#networking#welcome   1 min read
# 11                                                   3 min read
# 12                    #webdev#javascript#beginners   4 min read
# 13                       #webdev#node#java#mongodb   3 min read
# 14                #raspberrypi#python#ssh#bananapi   4 min read
# 15                                 #showdev#github   1 min read
# 16    #github#githubfoundation#githubcertification  12 min read
# 17                  #linux#fedora#hardware#samsung   5 min read
# 18   #blockchain#cryptocurrency#web3#smartcontract   4 min read
# 19        #samir#salih#samirsalih#digitalmarketing   4 min read
# 20                       #ai#llm#llminai#whatisllm   2 min read
# 21                          #aws#devops#automation   2 min read
# 22         #linux#programming#beginners#opensource   2 min read
# 23                  #ux#psychology#webdev#learning   4 min read
# 24               #c#programming#pointers#beginners   2 min read
#
#                                       Article Content  Word Count Sentiment  \
# 0   Hibernate is one of the most popular Object-Re...         306  Positive
# 1                                                               0   Neutral
# 2                                                               0   Neutral
# 3   Cloud computing simply means delivery of compu...         400  Positive
# 4   What is VIM? Basically, VIM will help you to c...         152  Positive
# 5                                                               0   Neutral
# 6   AI is here to stay. From my early days with th...         784  Positive
# 7    Recently, I started diving into the world of ...         758  Positive
# 8   In the realm of Java-based applications, Hiber...         268  Positive
# 9   names = ["Eren", "luffy", "goku"]\nprint(names...          31   Neutral
# 10                                                              0   Neutral
# 11  Использование discriminated unions в TypeScrip...         295  Positive
# 12  Una de las cosas mas complicadas al inicio de ...         220  Negative
# 13  Introduction Role-Based Authentication (RBA) i...         196  Positive
# 14  Este artigo irá demonstrar como fazer um LED p...         442  Negative
# 15                                                              0   Neutral
# 16  What folder is the definition files stored in ...         667  Positive
# 17  This guide walks you through every step—from i...         467  Positive
# 18  Blockchain technology is no longer just for cr...         740  Positive
# 19   The mental health industry has witnessed a si...         414  Positive
# 20  What is LLM in AI? This is the most asked ques...         238  Positive
# 21  This week, I deep-dived into Shell Scripting f...         179  Negative
# 22  Task scheduling is a fundamental aspect of Lin...         180  Positive
# 23   It was a quiet evening, and Alex was scrollin...         381  Positive
# 24  If you're diving into C programming, you've pr...         223  Positive
#
#     Compound Score
# 0           0.9970
# 1           0.0000
# 2           0.0000
# 3           0.9630
# 4           0.9825
# 5           0.0000
# 6           0.9992
# 7           0.9985
# 8           0.9908
# 9           0.0000
# 10          0.0000
# 11          0.8316
# 12         -0.6808
# 13          0.9633
# 14         -0.3595
# 15          0.0000
# 16          0.9981
# 17          0.9883
# 18          0.9962
# 19          0.9978
# 20          0.9925
# 21         -0.4003
# 22          0.4574
# 23          0.9972
# 24          0.9831
